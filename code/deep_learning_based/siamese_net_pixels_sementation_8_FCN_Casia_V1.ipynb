# %%
import cv2 
import numpy as np
import glob
import os
from itertools import combinations 
from itertools import product
import random
import matplotlib.pyplot as plt
from random import randrange
import sys
import math
#apt install python-pydot python-pydot-ng graphviz

# %%
import cv2 
import numpy as np
import glob
import os
from itertools import combinations 
from itertools import product
import random
import matplotlib.pyplot as plt
from random import randrange
import sys
#apt install python-pydot python-pydot-ng graphviz

# %%
# !{sys.executable} -m pip install pydot
# !{sys.executable} -m pip install pydotplus
# !{sys.executable} -m pip install graphviz
# Out:
# Collecting pydot
#   Downloading https://files.pythonhosted.org/packages/ea/76/75b1bb82e9bad3e3d656556eaa353d8cd17c4254393b08ec9786ac8ed273/pydot-1.4.2-py2.py3-none-any.whl
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.5/site-packages (from pydot)
# Installing collected packages: pydot
# Successfully installed pydot-1.4.2
# You are using pip version 9.0.3, however version 21.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting pydotplus
#   Downloading https://files.pythonhosted.org/packages/60/bf/62567830b700d9f6930e9ab6831d6ba256f7b0b730acb37278b0ccdffacf/pydotplus-2.0.2.tar.gz (278kB)
#     100% |████████████████████████████████| 286kB 4.0MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.0.1 in /usr/local/lib/python3.5/site-packages (from pydotplus)
# Building wheels for collected packages: pydotplus
#   Running setup.py bdist_wheel for pydotplus ... done
#   Stored in directory: /root/.cache/pip/wheels/35/7b/ab/66fb7b2ac1f6df87475b09dc48e707b6e0de80a6d8444e3628
# Successfully built pydotplus
# Installing collected packages: pydotplus
# Successfully installed pydotplus-2.0.2
# You are using pip version 9.0.3, however version 21.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting graphviz
#   Downloading https://files.pythonhosted.org/packages/1f/15/829918d2078de497d9905cb620be4e17caa75829d741a7c1649257316ea5/graphviz-0.14.2-py2.py3-none-any.whl
# Installing collected packages: graphviz
# Successfully installed graphviz-0.14.2
# You are using pip version 9.0.3, however version 21.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import tensorflow as tf 
from tensorflow.keras.layers import Dense, MaxPooling2D, Convolution2D, Dropout, Input, Flatten,Conv2D,Conv2DTranspose,Lambda,concatenate,GlobalMaxPooling2D,Activation
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model,Sequential
#from keras.initializers.h as 
from tensorflow.python.keras.utils.vis_utils import plot_model
from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#from tensorflow.python.keras.utils.vis_utils import plot_model
from tensorflow.keras.models import load_model
from tensorflow.keras.regularizers import l2 
from pandas import read_excel
import pydot
# !{sys.executable} -m pip install tensorflow-addons
import tensorflow_addons as tfa
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-e726a23fd0fc> in <module>
#       6 #from keras.initializers.h as
#       7 from tensorflow.python.keras.utils.vis_utils import plot_model
# ----> 8 from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       9 #from tensorflow.python.keras.utils.vis_utils import plot_model
#      10 from tensorflow.keras.models import load_model
#
# ImportError: No module named 'tensorflow.keras.layers.experimental'

# %%
path_input_images =  '/tensorflow/IITD_Database/'

# %%
mask_path  = '/tensorflow/iit_unet/mask_data/'

# %%
# data = read_excel(data_in_labels_path, sheetname='Sheet1')

# %%
# data.head()

# %%
def change_name(name):
    d = name.split('/')
    mask_name = 'frame' + '_' + d[0]+'_'+d[1] +'.png'
    return mask_name

# %%
#rows = data[data['image_name']=='001_04.bmp']

# %%
#rows['Y1p'].iloc[0]

# %%
def read_simaese_parametric_data(path_input_images, folder_name_list_batch,mask_path,batch_size):
    
    
    h  = 128
    w = 128 
    c = 1
    factor  = 4
    
    train_out1 = np.zeros((factor*batch_size,h,w,c),'float')
    train_out2 = np.zeros((factor*batch_size,h,w,c),'float')
    train_seg1 = np.zeros((factor*batch_size,h,w,1),'float')
    train_seg2 = np.zeros((factor*batch_size,h,w,1),'float')
    
    out1= np.zeros((factor*batch_size,h,w,c),'float')
    out2= np.zeros((factor*batch_size,h,w,c),'float')
    
    seg1= np.zeros((factor*batch_size,h,w,1),'float')
    seg2= np.zeros((factor*batch_size,h,w,1),'float')
    
    pos_comb1 = np.array(list(combinations([1, 2, 3, 4, 5], 2)))
    pos_comb2 = np.array(list(combinations([6, 7, 8, 9, 10], 2)))

    neg_comb1 = np.array(list(product([2,3,4,5], [8,9,10])))
    #
    count = 0
    y = []
    
    for folder_name in folder_name_list_batch:

        for j in range (len(pos_comb1)-9):
           
            i = random.randint(0, 9)
        
            ## read the image from folder in postive combination 
            #print('pos_combi =' + folder_name + '/'+ str(pos_comb1[i][0]).zfill(2)+'.bmp')
            img1_0 = cv2.imread(path_input_images + folder_name + '/'+ str(pos_comb1[i][0]).zfill(2)+'.bmp')
            
            
            img1_1 = cv2.imread(path_input_images + folder_name + '/'+ str(pos_comb1[i][1]).zfill(2)+'.bmp')
#             print('pos_combi =' + folder_name + '/'+ str(pos_comb1[i][1]).zfill(2)+'.bmp')

            img1_0 = cv2.resize(img1_0[:,:,0],(h,w))    #c = 1
            img1_1 = cv2.resize(img1_1[:,:,0],(h,w))
            ##get the correspondance segmentation data 
            name1 = folder_name + '/'+ str(pos_comb1[i][0]).zfill(2)
            name2 = folder_name + '/'+ str(pos_comb1[i][1]).zfill(2)
            seg1_0 = cv2.imread(mask_path + change_name(name1))
            seg1_1 = cv2.imread(mask_path + change_name(name2))
            ###############################################################
            seg1_0 = cv2.cvtColor(seg1_0,cv2.COLOR_BGR2GRAY)
            seg1_1 = cv2.cvtColor(seg1_1,cv2.COLOR_BGR2GRAY)
            
            seg1_0 = cv2.resize(seg1_0,(h,w))
            seg1_1 = cv2.resize(seg1_1,(h,w))
            
            ## save the image data to out and out2         
            out1[count]  = np.expand_dims(img1_0,axis=2) #img1_0
            out2[count]  = np.expand_dims(img1_1,axis=2) #img1_1
            seg1[count]  = np.expand_dims(seg1_0,axis=2)
            seg2[count]  = np.expand_dims(seg1_1,axis=2)
            
            #save the segmentation data to lable 

            
            ## posive combination assigning 0 to last clolumn
            y.append(1.0)
            
            ## increament the count
            count = count+1
            
            

            img2_0 = cv2.imread(path_input_images + folder_name + '/'+ str(pos_comb2[i][0]).zfill(2)+'.bmp')
            img2_1 = cv2.imread(path_input_images + folder_name + '/'+ str(pos_comb2[i][1]).zfill(2)+'.bmp')
            img2_0 = cv2.resize(img2_0[:,:,0],(h,w)) ## C = 1
            img2_1 = cv2.resize(img2_1[:,:,0],(h,w))  ## c = 1
            
            name1 = folder_name + '/'+ str(pos_comb2[i][0]).zfill(2)
            name2 = folder_name + '/'+ str(pos_comb2[i][1]).zfill(2)
            seg2_0 = cv2.imread(mask_path + change_name(name1))
            seg2_1 = cv2.imread(mask_path + change_name(name2)) 
            
            seg2_0 = cv2.cvtColor(seg2_0,cv2.COLOR_BGR2GRAY)
            seg2_1 = cv2.cvtColor(seg2_1,cv2.COLOR_BGR2GRAY)
            seg2_0 = cv2.resize(seg2_0,(h,w))
            seg2_1 = cv2.resize(seg2_1,(h,w))
            out1[count]  = np.expand_dims(img2_0,axis=2)#img2_0
            out2[count]  = np.expand_dims(img2_1,axis=2)#img2_1
            seg1[count]  = np.expand_dims(seg2_0,axis=2)
            seg2[count]  = np.expand_dims(seg2_1,axis=2)          

            y.append(1.0)
            count = count+1

            
            ## negative combination left vs right iris for same person 
            folder_name2 = str(int(folder_name) + 1).zfill(3)
#             print('neg_combi =' + folder_name2 + '/'+ str(neg_comb1[i][1]).zfill(2)+'.bmp')
#             print('neg_combi =' + folder_name + '/'+ str(neg_comb1[i][0]).zfill(2)+'.bmp')
            img3_0 = cv2.imread(path_input_images + folder_name + '/'+ str(neg_comb1[i][0]).zfill(2)+'.bmp')
            img3_1 = cv2.imread(path_input_images + folder_name2 + '/'+ str(neg_comb1[i][1]).zfill(2)+'.bmp')
            img3_0 = cv2.resize(img3_0[:,:,0],(h,w))  #c = 1
            img3_1 = cv2.resize(img3_1[:,:,0],(h,w))
            
            name1 = folder_name + '/'+ str(neg_comb1[i][0]).zfill(2)
            name2 = folder_name + '/'+ str(neg_comb1[i][1]).zfill(2)
            seg3_0 = cv2.imread(mask_path + change_name(name1))
            seg3_1 = cv2.imread(mask_path + change_name(name2))
            
            seg3_0 = cv2.cvtColor(seg3_0,cv2.COLOR_BGR2GRAY)
            seg3_1 = cv2.cvtColor(seg3_1,cv2.COLOR_BGR2GRAY)
            
            seg3_0 = cv2.resize(seg3_0,(h,w))
            seg3_1 = cv2.resize(seg3_1,(h,w))
            
            out1[count]  = np.expand_dims(img3_0,axis=2) #img3_0
            out2[count]  = np.expand_dims(img3_1,axis=2) #img3_1
            seg1[count]  = np.expand_dims(seg3_0,axis=2)
            seg2[count]  = np.expand_dims(seg3_1,axis=2)
            ## assigning 1 to negative combinations (left vs right image)
            y.append(0.0)
            count = count+1

            
            ## creating the negativ combination from diffrent person 
            folder_name1 = str(int(folder_name) + 3).zfill(3) 
            img4_0 = cv2.imread(path_input_images + folder_name + '/'+ str(pos_comb1[i][0]).zfill(2)+'.bmp')
            img4_1 = cv2.imread(path_input_images + folder_name1 + '/'+ str(pos_comb1[i][1]).zfill(2)+'.bmp')

            img4_0 = cv2.resize(img4_0[:,:,0],(h,w))
            img4_1 = cv2.resize(img4_1[:,:,0],(h,w))
            name1 = folder_name + '/'+ str(pos_comb1[i][0]).zfill(2)
            name2 = folder_name1 + '/'+ str(pos_comb1[i][1]).zfill(2)
            seg4_0 = cv2.imread(mask_path + change_name(name1))
            seg4_1 = cv2.imread(mask_path + change_name(name2))

            seg4_0 = cv2.cvtColor(seg4_0,cv2.COLOR_BGR2GRAY)
            seg4_1 = cv2.cvtColor(seg4_1,cv2.COLOR_BGR2GRAY)        

            seg4_0 = cv2.resize(seg4_0,(h,w))
            seg4_1 = cv2.resize(seg4_1,(h,w))
            
            out1[count]  = np.expand_dims(img4_0,axis=2)#img4_0
            out2[count]  = np.expand_dims(img4_1,axis=2) #img4_1
            seg1[count]  = np.expand_dims(seg4_0,axis=2)
            seg2[count]  = np.expand_dims(seg4_1,axis=2)
            y.append(0.0)
            count = count+1
            #print(i)
            
    ## this padding the data set for size 256x512 to maintain spect rationa nd segmentation parameters 
    train_out1 = out1
    train_out2 = out2 
    
    train_seg1 = seg1
    train_seg2 = seg2  
    
    
#     train_out1[:,0:240,0:320,:] = out1
#     train_out2[:,0:240,0:320,:] = out2 
    
#     train_seg1[:,0:240,0:320,:] = seg1
#     train_seg2[:,0:240,0:320,:] = seg2     
    
    return train_out1,train_out2,train_seg1,train_seg2,y
        #print(count)

# %%
#print(np.array(list(product([2,3,4,5], [8,9,10]))))
print(np.array(list(combinations([1, 2, 3, 4, 5], 2))))
# Out:
# [[1 2]
#  [1 3]
#  [1 4]
#  [1 5]
#  [2 3]
#  [2 4]
#  [2 5]
#  [3 4]
#  [3 5]
#  [4 5]]

# %%
#fileList = listOfFiles     
def imageLoader(path_input_images,folder_name_list,mask_path,batch_size):

    L = len(folder_name_list)

    #this line is just to make the generator infinite, keras needs that    
    while True:

        batch_start = randrange(L-batch_size)
        batch_end = batch_start + batch_size

        if (batch_end < L):
            limit = min(batch_end, L)
            train_out1,train_out2,train_seg1,train_seg2,y_class = read_simaese_parametric_data(path_input_images,folder_name_list[batch_start:limit],mask_path,batch_size)
            train_out1 = train_out1/255.
            train_out2 = train_out2/255.
            train_seg1 = train_seg1/255.
            train_seg2 = train_seg2/255.
            batch_start = batch_end
            batch_end = batch_start + batch_size
            #print(batch_start,batch_end)
            ## just for the test 
            #yield (train_out2,train_seg2)
            ## original
            yield ([train_out1,train_out2],[train_seg1,train_seg2,np.array(y_class)]) #a tuple with two numpy arrays with batch_size samples

# %%
folder_names = np.sort(os.listdir(path_input_images))
folder_name_list = folder_names[0:120] 
folder_name_list_test = folder_names[120:220]
print(len(folder_name_list_test))
# Out:
# 100

# %% [markdown]
# ### Function to check the GT and loader

# %%
def draw_haugh_circle(img_L,img_R, hough_param):        
    
    
    print('pair_classification =', int(hough_param[12]))
    cimg = img_L.copy()
    cv2.circle(cimg,(int(hough_param[0]),int(hough_param[1])),int(hough_param[2]),(0,255,0),2)
                # draw the center of the circle
    cv2.circle(cimg,(int(hough_param[0]),int(hough_param[1])),2,(0,255,0),3)

                #for i in circles_inner[0,:]:
                # draw the outer circle
    cv2.circle(cimg,(int(hough_param[3]),int(hough_param[4])),int(hough_param[5]),(0,0,255),2)
                # draw the center of the circle
    cv2.circle(cimg,(int(hough_param[3]),int(hough_param[4])),2,(0,0,255),3)
    plt.title('left_image')
    plt.imshow(cimg)
    plt.show()
    
    
    cimg = img_R.copy()
    cv2.circle(cimg,(int(hough_param[6]),int(hough_param[7])),int(hough_param[8]),(0,255,0),2)
                # draw the center of the circle
    cv2.circle(cimg,(int(hough_param[6]),int(hough_param[7])),2,(0,255,0),3)

                #for i in circles_inner[0,:]:
                # draw the outer circle
    cv2.circle(cimg,(int(hough_param[9]),int(hough_param[10])),int(hough_param[11]),(0,0,255),2)
                # draw the center of the circle
    cv2.circle(cimg,(int(hough_param[9]),int(hough_param[10])),2,(0,0,255),3)
    plt.title('right_image')
    plt.imshow(cimg)
    plt.show()

# %%
g=0
while (g < 200):

    Out = next(imageLoader(path_input_images,folder_name_list,mask_path,4))
    g = g+1

# %%
images_L_R = Out[0]
image_L = images_L_R[0]
image_R = images_L_R[1]

mask_L_R_class = Out[1]

mask_L = mask_L_R_class[0]
mask_R = mask_L_R_class[1]
y = mask_L_R_class[2]
print(y[0])
print(image_L.shape)
# Out:
# 1.0
# (16, 128, 128, 1)

# %% [markdown]
# # mask_L.shape

# %%
plt.title('left_image')
plt.imshow(image_R[1],cmap='gray')
plt.show()

# %%
plt.title('left_mask')
plt.imshow(np.squeeze(mask_R[1]))
plt.show()

# %%
#pos_comb1 = np.array(list(combinations([1, 2, 3, 4, 5], 2)))
#pos_comb2 = np.array(list(combinations([6, 7, 8, 9, 10], 2)))

#neg_comb1 = np.array(list(product([2,3,4,5], [8,9,10])))
#print(neg_comb1)

# %%
folder_names = np.sort(os.listdir(path_input_images))

print(folder_names[0:20])
# Out:
# ['001' '002' '003' '004' '005' '006' '007' '008' '009' '010' '011' '012'
#  '013' '014' '015' '016' '017' '018' '019' '020']

# %%
# def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
#     """Function to add 2 convolutional layers with the parameters passed to it"""
#     # first layer
#     x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
#               kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
#     if batchnorm:
#         x = BatchNormalization()(x)
#     x = Activation('relu')(x)
    
#     # second layer
#     x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
#               kernel_initializer = 'he_normal', padding = 'same')(x)
#     if batchnorm:
#         x = BatchNormalization()(x)
#     x = Activation('relu')(x)
    
#     return x

# %%
initialize_weights = 'he_normal'
initialize_bias = 'he_normal'

# %%
def base_network_unet():
    input = Input(shape=(128,128,1), name="base_input")
    n_filters=16
    dropout=.1
    batchnorm=True
       
    c1 = Conv2D(n_filters*1, (3,3), activation='relu',
                   kernel_initializer=initialize_weights,padding = 'same', kernel_regularizer=l2(2e-4))(input)
    p1 = MaxPooling2D((2,2))(c1)           # (h/2,w/2,16)
    p1 = Dropout(dropout)(p1) 

    c2 = Conv2D(n_filters*2, (3,3), activation='relu',
                   kernel_initializer=initialize_weights,padding = 'same', kernel_regularizer=l2(2e-4))(p1)
    p2 = MaxPooling2D((2,2))(c2)  # (h/4,w/4,32)
    p2 = Dropout(dropout)(p2) 

    c3 = Conv2D(n_filters*4, (3,3), activation='relu',
                   kernel_initializer=initialize_weights, padding = 'same', kernel_regularizer=l2(2e-4))(p2)
    p3 = MaxPooling2D((2,2))(c3)  # (h/8,w/8,64)
    p3 = Dropout(dropout)(p3) 

    c4 = Conv2D(n_filters*8, (3,3), activation='relu',
                   kernel_initializer=initialize_weights, padding = 'same', kernel_regularizer=l2(2e-4))(p3)
    p4 = MaxPooling2D((2,2))(c4)  # (h/16,w/16,128)
    p4 = Dropout(dropout)(p4) 

    c5 = Conv2D(n_filters*16, (3,3), activation='relu',
                   kernel_initializer=initialize_weights, padding = 'same', kernel_regularizer=l2(2e-4))(p4)      # (h/16,w/16,256)


    print("encoder done")


    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)  # (h/8,w/8,128)
    u6 = concatenate([u6, c4])   # (h/8,w/8,128)
    u6 = Dropout(dropout)(u6)
        
    c6 = Conv2D(n_filters*8, (3,3), activation='relu',
                   kernel_initializer=initialize_weights, padding = 'same', kernel_regularizer=l2(2e-4))(u6) # (h/8,w/8,128)

    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)  # (h/4,w/4,64)
    u7 = concatenate([u7, c3])   # (h/8,w/8,128)
    u7 = Dropout(dropout)(u7)
    c7 = Conv2D(n_filters*4, (3,3), activation='relu',
                   kernel_initializer=initialize_weights, padding = 'same', kernel_regularizer=l2(2e-4))(u7) # (h/4,w/4,64)

    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)  # (h/2,w/2,32)
    u8 = concatenate([u8, c2])   # (h/2,w/2,32)
    u8 = Dropout(dropout)(u8)
    c8 = Conv2D(n_filters*2, (3,3), activation='relu',
                   kernel_initializer=initialize_weights, padding = 'same', kernel_regularizer=l2(2e-4))(u8)     # (h/2,w/2,32)

    u9 = Conv2DTranspose(n_filters, (3, 3), strides = (2, 2), padding = 'same')(c8)  # (h,w,16)
    u9 = concatenate([u9, c1])   # (h,w,16)
    u9 = Dropout(dropout)(u9)
    c9 = Conv2D(n_filters, (3,3), activation='relu',
                   kernel_initializer=initialize_weights, padding = 'same', kernel_regularizer=l2(2e-4))(u9)     # (h,w,16)    


    print("decoder done . . .  siamese network will start" )
    X_outputs = Conv2D(1,(1,1),activation='sigmoid',name='seg_out')(c9)
   
    print("simaese model done")
    return Model(inputs=input, outputs=[X_outputs,c9])

# %%
def base_network_siamese():
    
    input = Input(shape=(128,128,16), name="base_input")
#     degrees  = tf.constant(0,dtype='float32')
#     r1 = tfa.image.rotate(input[0],input[1])
    
    c10 = Conv2D(64, (10,10), activation='relu',
                   kernel_initializer=initialize_weights, kernel_regularizer=l2(2e-4))(input)
    p10 = MaxPooling2D()(c10)
    
#     r10 = tfa.image.rotate(p10,degrees, interpolation='BILINEAR')
    
    c11 = Conv2D(128, (7,7), activation='relu',
                     kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4))(p10)
    p11 = MaxPooling2D()(c11)
    c12 = Conv2D(128, (4,4), activation='relu', kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4))(p11)
    p12 = MaxPooling2D()(c12)
    c13 = Conv2D(256, (4,4), activation='relu', kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4))(p12)
    a1 = Flatten()(c13)
    a2 = Dense(128, activation='relu',
                   kernel_regularizer=l2(1e-3),
                   kernel_initializer=initialize_weights,bias_initializer=initialize_bias)(a1)  
    
    print("simaese model done")
    return Model(inputs=input, outputs=a2)

# %%
def euclidean_distance(vects):
    x, y = vects
    
    x0, x1, x2, x3, x4 = tf.split(x, num_or_size_splits=5, axis=1)
    
    y0, y1, y2, y3, y4 = tf.split(y, num_or_size_splits=5, axis=1)

#     v_size =128
#     sum_square_1 = K.sum(K.square(x[0:128] - y[0:128]), axis=1, keepdims=True)           ## batch_size x 1 
#     sum_square_2 = K.sum(K.square(x[0:128] - y[128:2*128]), axis=1, keepdims=True)    ## batch_size x 1 
#     sum_square_3 = K.sum(K.square(x[0:128] - y[2*128:3*128]), axis=1, keepdims=True)    ## batch_size x 1 
#     sum_square_4 = K.sum(K.square(x[0:128] - y[3*128:4*128]), axis=1, keepdims=True)    ## batch_size x 1 
#     sum_square_5 = K.sum(K.square(x[0:128] - y[4*128:5*128]), axis=1, keepdims=True)    ## batch_size x 1 
    
    
#     min_sum_square1 =  K.minimum(sum_square_1,sum_square_2)
#     min_sum_square2 = K.minimum(sum_square_3,sum_square_4)
#     min_sum_square3 = K.minimum(min_sum_square1,min_sum_square2)
#     min_sum_square4 = K.minimum(min_sum_square3,sum_square_5)
    
    
    
    sum_square_1 = K.sum(K.square(x0 - y0), axis=1, keepdims=True)           ## batch_size x 1 
    sum_square_2 = K.sum(K.square(x0 - y1), axis=1, keepdims=True)    ## batch_size x 1 
    sum_square_3 = K.sum(K.square(x0 - y2), axis=1, keepdims=True)    ## batch_size x 1 
    sum_square_4 = K.sum(K.square(x0 - y3), axis=1, keepdims=True)    ## batch_size x 1 
    sum_square_5 = K.sum(K.square(x0 - y4), axis=1, keepdims=True)    ## batch_size x 1 
    
    
    min_sum_square1 =  K.minimum(sum_square_1,sum_square_2)
    min_sum_square2 = K.minimum(sum_square_3,sum_square_4)
    min_sum_square3 = K.minimum(min_sum_square1,min_sum_square2)
    min_sum_square4 = K.minimum(min_sum_square3,sum_square_5) 
    
    
    
    return K.sqrt(K.maximum(min_sum_square4, K.epsilon()))


def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

# %%
base_network_1 = base_network_unet()
plot_model(base_network_1, show_shapes=True, show_layer_names=True, to_file='base-model.png')
# Out:
# encoder done
# decoder done . . .  siamese network will start
# simaese model done

# %%
base_network_2 = base_network_siamese()
plot_model(base_network_2, show_shapes=True, show_layer_names=True, to_file='base-model.png')
# Out:
# simaese model done

# %%
# create the left input and point to the base network
input_a = Input(shape=(128,128,1), name="left_input")

seg_a , seg_logit_a = base_network_1(input_a)

# create the right input and point to the base network
input_b = Input(shape=(128,128,1), name="right_input")

seg_b, seg_logit_b = base_network_1(input_b)

degree_1  = (2*np.pi/360)
delta = .000001


seg_logit_b_1 = RandomRotation(factor=(degree_1,degree_1+delta))(seg_logit_b)
seg_logit_b_2 = RandomRotation(factor=(2*degree_1,2*degree_1+delta))(seg_logit_b)
seg_logit_b_n1 = RandomRotation(factor=(-1*degree_1,-1*degree_1+delta))(seg_logit_b)
seg_logit_b_n2 = RandomRotation(factor=(-2*degree_1,-2*degree_1+delta))(seg_logit_b)


vect_a0 = base_network_2(seg_logit_a)





vect_0 = base_network_2(seg_logit_b)
vect_1 = base_network_2(seg_logit_b_1)
vect_2 = base_network_2(seg_logit_b_2)
vect_n1 = base_network_2(seg_logit_b_n1)
vect_n2 = base_network_2(seg_logit_b_n2)

vect_output_b = concatenate([vect_0, vect_1, vect_2, vect_n1, vect_n2]) 

vect_output_a = concatenate([vect_a0, vect_1, vect_2, vect_n1, vect_n2])  

# # measure the similarity of the two vector outputs
output_siasmese = Lambda(euclidean_distance, name="output_layer", output_shape=(128,1))([vect_output_a, vect_output_b])

# # specify the inputs and output of the model
model = Model([input_a, input_b], [seg_a,seg_b,output_siasmese])

# %%
plot_model(model, show_shapes=True, show_layer_names=True, to_file='outer-model.png')

# %%
def contrastive_loss_with_margin(margin):
    def contrastive_loss(y_true, y_pred):
        '''Contrastive loss from Hadsell-et-al.'06
        http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
        '''
        square_pred = K.square(y_pred)
        margin_square = K.square(K.maximum(margin - y_pred, 0))
        return K.mean(y_true * square_pred + (1 - y_true) * margin_square)
    return contrastive_loss

# %%
#optimizer = keras.optimizers.Adam(lr = 0.0001)


#siamese_model.compile(loss=custom_loss, optimizer=optimizer, metrics = ['mae', 'acc'])
model.compile(loss = {'model_5' : "binary_crossentropy",
                      'model_5_1' : "binary_crossentropy",
                      'output_layer' : contrastive_loss_with_margin(margin=1)
                     },optimizer='Adam', metrics = ['mae', 'acc'])

# %%
#steps_per_epoch = train_length // batch_size
batch_size = 4
steps_per_epoch = len(folder_name_list) // batch_size
validation_steps = len(folder_name_list_test) // batch_size

# %%
# history = siamese_model.fit_generator(imageLoader(path_input_images,folder_name_list,batch_size),steps_per_epoch,
#                     validation_data = imageLoader(path_input_images,folder_name_list_test,batch_size), 
#                     validation_steps=validation_steps, epochs=50)

# %%
history = model.fit_generator(imageLoader(path_input_images,folder_name_list,mask_path,batch_size),steps_per_epoch,
                    validation_data = imageLoader(path_input_images,folder_name_list_test,mask_path,batch_size), 
                    validation_steps=validation_steps, epochs=140)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/140
# 30/30 [==============================] - 309s 10s/step - loss: 0.3492 - model_5_loss: 0.0646 - model_5_1_loss: 0.2054 - output_layer_loss: 0.0195 - model_5_model_5_model_5_mae: 0.0463 - model_5_model_5_model_5_acc: 0.9737 - model_5_1_model_5_1_model_5_1_mae: 0.1041 - model_5_1_model_5_1_model_5_1_acc: 0.9134 - output_layer_output_layer_output_layer_mae: 1.0990 - output_layer_output_layer_output_layer_acc: 0.0042 - val_loss: 0.4228 - val_model_5_loss: 0.0773 - val_model_5_1_loss: 0.2402 - val_output_layer_loss: 0.0461 - val_model_5_model_5_model_5_mae: 0.0473 - val_model_5_model_5_model_5_acc: 0.9664 - val_model_5_1_model_5_1_model_5_1_mae: 0.1022 - val_model_5_1_model_5_1_model_5_1_acc: 0.9126 - val_output_layer_output_layer_output_layer_mae: 1.0423 - val_output_layer_output_layer_output_layer_acc: 0.0550
140
# 30/30 [==============================] - 305s 10s/step - loss: 0.2913 - model_5_loss: 0.0573 - model_5_1_loss: 0.1745 - output_layer_loss: 0.0141 - model_5_model_5_model_5_mae: 0.0398 - model_5_model_5_model_5_acc: 0.9753 - model_5_1_model_5_1_model_5_1_mae: 0.0926 - model_5_1_model_5_1_model_5_1_acc: 0.9212 - output_layer_output_layer_output_layer_mae: 1.1262 - output_layer_output_layer_output_layer_acc: 0.0063 - val_loss: 0.4214 - val_model_5_loss: 0.0793 - val_model_5_1_loss: 0.2517 - val_output_layer_loss: 0.0451 - val_model_5_model_5_model_5_mae: 0.0459 - val_model_5_model_5_model_5_acc: 0.9653 - val_model_5_1_model_5_1_model_5_1_mae: 0.1002 - val_model_5_1_model_5_1_model_5_1_acc: 0.9115 - val_output_layer_output_layer_output_layer_mae: 1.0877 - val_output_layer_output_layer_output_layer_acc: 0.0475
# Epoch 49/140
# 30/30 [==============================] - 305s 10s/step - loss: 0.2875 - model_5_loss: 0.0557 - model_5_1_loss: 0.1746 - output_layer_loss: 0.0119 - model_5_model_5_model_5_mae: 0.0385 - model_5_model_5_model_5_acc: 0.9755 - model_5_1_model_5_1_model_5_1_mae: 0.0905 - model_5_1_model_5_1_model_5_1_acc: 0.9232 - output_layer_output_layer_output_layer_mae: 1.1796 - output_layer_output_layer_output_layer_acc: 0.0021 - val_loss: 0.3729 - val_model_5_loss: 0.0710 - val_model_5_1_loss: 0.2089 - val_output_layer_loss: 0.0478 - val_model_5_model_5_model_5_mae: 0.0489 - val_model_5_model_5_model_5_acc: 0.9705 - val_model_5_1_model_5_1_model_5_1_mae: 0.1041 - val_model_5_1_model_5_1_model_5_1_acc: 0.9165 - val_output_layer_output_layer_output_layer_mae: 1.0584 - val_output_layer_output_layer_output_layer_acc: 0.0600
# Epoch 50/140
# 30/30 [==============================] - 305s 10s/step - loss: 0.2954 - model_5_loss: 0.0565 - model_5_1_loss: 0.1797 - output_layer_loss: 0.0135 - model_5_model_5_model_5_mae: 0.0395 - model_5_model_5_model_5_acc: 0.9760 - model_5_1_model_5_1_model_5_1_mae: 0.0965 - model_5_1_model_5_1_model_5_1_acc: 0.9183 - output_layer_output_layer_output_layer_mae: 1.1174 - output_layer_output_layer_output_layer_acc: 0.0042 - val_loss: 0.3989 - val_model_5_loss: 0.0692 - val_model_5_1_loss: 0.2317 - val_output_layer_loss: 0.0521 - val_model_5_model_5_model_5_mae: 0.0460 - val_model_5_model_5_model_5_acc: 0.9692 - val_model_5_1_model_5_1_model_5_1_mae: 0.1031 - val_model_5_1_model_5_1_model_5_1_acc: 0.9125 - val_output_layer_output_layer_output_layer_mae: 1.0054 - val_output_layer_output_layer_output_layer_acc: 0.0525
# Epoch 51/140
# 30/30 [==============================] - 305s 10s/step - loss: 0.2875 - model_5_loss: 0.0562 - model_5_1_loss: 0.1733 - output_layer_loss: 0.0121 - model_5_model_5_model_5_mae: 0.0388 - model_5_model_5_model_5_acc: 0.9754 - model_5_1_model_5_1_model_5_1_mae: 0.0919 - model_5_1_model_5_1_model_5_1_acc: 0.9209 - output_layer_output_layer_output_layer_mae: 1.0917 - output_layer_output_layer_output_layer_acc: 0.0021 - val_loss: 0.3913 - val_model_5_loss: 0.0657 - val_model_5_1_loss: 0.2382 - val_output_layer_loss: 0.0416 - val_model_5_model_5_model_5_mae: 0.0422 - val_model_5_model_5_model_5_acc: 0.9699 - val_model_5_1_model_5_1_model_5_1_mae: 0.1014 - val_model_5_1_model_5_1_model_5_1_acc: 0.9119 - val_output_layer_output_layer_output_layer_mae: 1.0834 - val_output_layer_output_layer_output_layer_acc: 0.0375
# Epoch 52/140
# 30/30 [==============================] - 305s 10s/step - loss: 0.3099 - model_5_loss: 0.0626 - model_5_1_loss: 0.1864 - output_layer_loss: 0.0151 - model_5_model_5_model_5_mae: 0.0444 - model_5_model_5_model_5_acc: 0.9742 - model_5_1_model_5_1_model_5_1_mae: 0.0969 - model_5_1_model_5_1_model_5_1_acc: 0.9193 - output_layer_output_layer_output_layer_mae: 1.1139 - output_layer_output_layer_output_layer_acc: 0.0042 - val_loss: 0.3978 - val_model_5_loss: 0.0676 - val_model_5_1_loss: 0.2397 - val_output_layer_loss: 0.0446 - val_model_5_model_5_model_5_mae: 0.0440 - val_model_5_model_5_model_5_acc: 0.9695 - val_model_5_1_model_5_1_model_5_1_mae: 0.0998 - val_model_5_1_model_5_1_model_5_1_acc: 0.9139 - val_output_layer_output_layer_output_layer_mae: 1.0670 - val_output_layer_output_layer_output_layer_acc: 0.0400
# Epoch 53/140
# 30/30 [==============================] - 305s 10s/step - loss: 0.2903 - model_5_loss: 0.0581 - model_5_1_loss: 0.1756 - output_layer_loss: 0.0108 - model_5_model_5_model_5_mae: 0.0395 - model_5_model_5_model_5_acc: 0.9743 - model_5_1_model_5_1_model_5_1_mae: 0.0931 - model_5_1_model_5_1_model_5_1_acc: 0.9205 - output_layer_output_layer_output_layer_mae: 1.1760 - output_layer_output_layer_output_layer_acc: 0.0021 - val_loss: 0.3965 - val_model_5_loss: 0.0736 - val_model_5_1_loss: 0.2300 - val_output_layer_loss: 0.0473 - val_model_5_model_5_model_5_mae: 0.0463 - val_model_5_model_5_model_5_acc: 0.9679 - val_model_5_1_model_5_1_model_5_1_mae: 0.0986 - val_model_5_1_model_5_1_model_5_1_acc: 0.9157 - val_output_layer_output_layer_output_layer_mae: 1.1032 - val_output_layer_output_layer_output_layer_acc: 0.0550
# Epoch 54/140
# 30/30 [==============================] - 305s 10s/step - loss: 0.2830 - model_5_loss: 0.0555 - model_5_1_loss: 0.1697 - output_layer_loss: 0.0124 - model_5_model_5_model_5_mae: 0.0379 - model_5_model_5_model_5_acc: 0.9754 - model_5_1_model_5_1_model_5_1_mae: 0.0915 - model_5_1_model_5_1_model_5_1_acc: 0.9218 - output_layer_output_layer_output_layer_mae: 1.1663 - output_layer_output_layer_output_layer_acc: 0.0021 - val_loss: 0.3857 - val_model_5_loss: 0.0705 - val_model_5_1_loss: 0.2248 - val_output_layer_loss: 0.0453 - val_model_5_model_5_model_5_mae: 0.0460 - val_model_5_model_5_model_5_acc: 0.9692 - val_model_5_1_model_5_1_model_5_1_mae: 0.1012 - val_model_5_1_model_5_1_model_5_1_acc: 0.9136 - val_output_layer_output_layer_output_layer_mae: 1.0928 - val_output_layer_output_layer_output_layer_acc: 0.0425
# Epoch 55/140
# 30/30 [==============================] - 305s 10s/step - loss: 0.2891 - model_5_loss: 0.0571 - model_5_1_loss: 0.1739 - output_layer_loss: 0.0131 - model_5_model_5_model_5_mae: 0.0395 - model_5_model_5_model_5_acc: 0.9751 - model_5_1_model_5_1_model_5_1_mae: 0.0930 - model_5_1_model_5_1_model_5_1_acc: 0.9209 - output_layer_output_layer_output_layer_mae: 1.1540 - output_layer_output_layer_output_layer_acc: 0.0021 - val_loss: 0.4008 - val_model_5_loss: 0.0631 - val_model_5_1_loss: 0.2465 - val_output_layer_loss: 0.0463 - val_model_5_model_5_model_5_mae: 0.0395 - val_model_5_model_5_model_5_acc: 0.9701 - val_model_5_1_model_5_1_model_5_1_mae: 0.0934 - val_model_5_1_model_5_1_model_5_1_acc: 0.9158 - val_output_layer_output_layer_output_layer_mae: 1.0944 - val_output_layer_output_layer_output_layer_acc: 0.0525
# Epoch 56/140
# 30/30 [==============================] - 305s 10s/step - loss: 0.2855 - model_5_loss: 0.0555 - model_5_1_loss: 0.1741 - output_layer_loss: 0.0111 - model_5_model_5_model_5_mae: 0.0386 - model_5_model_5_model_5_acc: 0.9759 - model_5_1_model_5_1_model_5_1_mae: 0.0931 - model_5_1_model_5_1_model_5_1_acc: 0.9202 - output_layer_output_layer_output_layer_mae: 1.1670 - output_layer_output_layer_output_layer_acc: 0.0000e+00 - val_loss: 0.3801 - val_model_5_loss: 0.0747 - val_model_5_1_loss: 0.2121 - val_output_layer_loss: 0.0485 - val_model_5_model_5_model_5_mae: 0.0508 - val_model_5_model_5_model_5_acc: 0.9687 - val_model_5_1_model_5_1_model_5_1_mae: 0.1025 - val_model_5_1_model_5_1_model_5_1_acc: 0.9170 - val_output_layer_output_layer_output_layer_mae: 0.9997 - val_output_layer_output_layer_output_layer_acc: 0.0500
# Epoch 57/140
# 30/30 [==============================] - 305s 10s/step - loss: 0.2829 - model_5_loss: 0.0554 - model_5_1_loss: 0.1718 - output_layer_loss: 0.0110 - model_5_model_5_model_5_mae: 0.0382 - model_5_model_5_model_5_acc: 0.9758 - model_5_1_model_5_1_model_5_1_mae: 0.0936 - model_5_1_model_5_1_model_5_1_acc: 0.9202 - output_layer_output_layer_output_layer_mae: 1.1606 - output_layer_output_layer_output_layer_acc: 0.0042 - val_loss: 0.4105 - val_model_5_loss: 0.0708 - val_model_5_1_loss: 0.2547 - val_output_layer_loss: 0.0405 - val_model_5_model_5_model_5_mae: 0.0433 - val_model_5_model_5_model_5_acc: 0.9678 - val_model_5_1_model_5_1_model_5_1_mae: 0.0997 - val_model_5_1_model_5_1_model_5_1_acc: 0.9119 - val_output_layer_output_layer_output_layer_mae: 1.0978 - val_output_layer_output_layer_output_layer_acc: 0.0300
# Epoch 58/140
# ...
# Epoch 122/140
# 30/30 [==============================] - 306s 10s/step - loss: 0.2744 - model_5_loss: 0.0528 - model_5_1_loss: 0.1637 - output_layer_loss: 0.0143 - model_5_model_5_model_5_mae: 0.0360 - model_5_model_5_model_5_acc: 0.9759 - model_5_1_model_5_1_model_5_1_mae: 0.0861 - model_5_1_model_5_1_model_5_1_acc: 0.9246 - output_layer_output_layer_output_layer_mae: 1.1707 - output_layer_output_layer_output_layer_acc: 0.0021 - val_loss: 0.3848 - val_model_5_loss: 0.0738 - val_model_5_1_loss: 0.2161 - val_output_layer_loss: 0.0511 - val_model_5_model_5_model_5_mae: 0.0510 - val_model_5_model_5_model_5_acc: 0.9699 - val_model_5_1_model_5_1_model_5_1_mae: 0.1010 - val_model_5_1_model_5_1_model_5_1_acc: 0.9188 - val_output_layer_output_layer_output_layer_mae: 1.0584 - val_output_layer_output_layer_output_layer_acc: 0.0575
# Epoch 123/140
# 30/30 [==============================] - 305s 10s/step - loss: 0.2711 - model_5_loss: 0.0525 - model_5_1_loss: 0.1638 - output_layer_loss: 0.0112 - model_5_model_5_model_5_mae: 0.0358 - model_5_model_5_model_5_acc: 0.9763 - model_5_1_model_5_1_model_5_1_mae: 0.0910 - model_5_1_model_5_1_model_5_1_acc: 0.9201 - output_layer_output_layer_output_layer_mae: 1.1139 - output_layer_output_layer_output_layer_acc: 0.0042 - val_loss: 0.4209 - val_model_5_loss: 0.0599 - val_model_5_1_loss: 0.2645 - val_output_layer_loss: 0.0530 - val_model_5_model_5_model_5_mae: 0.0356 - val_model_5_model_5_model_5_acc: 0.9708 - val_model_5_1_model_5_1_model_5_1_mae: 0.0927 - val_model_5_1_model_5_1_model_5_1_acc: 0.9124 - val_output_layer_output_layer_output_layer_mae: 1.0709 - val_output_layer_output_layer_output_layer_acc: 0.0675
# Epoch 124/140
# 30/30 [==============================] - 306s 10s/step - loss: 0.2622 - model_5_loss: 0.0514 - model_5_1_loss: 0.1558 - output_layer_loss: 0.0117 - model_5_model_5_model_5_mae: 0.0345 - model_5_model_5_model_5_acc: 0.9765 - model_5_1_model_5_1_model_5_1_mae: 0.0850 - model_5_1_model_5_1_model_5_1_acc: 0.9247 - output_layer_output_layer_output_layer_mae: 1.1372 - output_layer_output_layer_output_layer_acc: 0.0021 - val_loss: 0.4061 - val_model_5_loss: 0.0812 - val_model_5_1_loss: 0.2356 - val_output_layer_loss: 0.0460 - val_model_5_model_5_model_5_mae: 0.0538 - val_model_5_model_5_model_5_acc: 0.9629 - val_model_5_1_model_5_1_model_5_1_mae: 0.1116 - val_model_5_1_model_5_1_model_5_1_acc: 0.9064 - val_output_layer_output_layer_output_layer_mae: 1.1128 - val_output_layer_output_layer_output_layer_acc: 0.0475
# Epoch 125/140
# 30/30 [==============================] - 306s 10s/step - loss: 0.2711 - model_5_loss: 0.0551 - model_5_1_loss: 0.1648 - output_layer_loss: 0.0081 - model_5_model_5_model_5_mae: 0.0381 - model_5_model_5_model_5_acc: 0.9757 - model_5_1_model_5_1_model_5_1_mae: 0.0885 - model_5_1_model_5_1_model_5_1_acc: 0.9237 - output_layer_output_layer_output_layer_mae: 1.2029 - output_layer_output_layer_output_layer_acc: 0.0000e+00 - val_loss: 0.4341 - val_model_5_loss: 0.0557 - val_model_5_1_loss: 0.2830 - val_output_layer_loss: 0.0523 - val_model_5_model_5_model_5_mae: 0.0322 - val_model_5_model_5_model_5_acc: 0.9716 - val_model_5_1_model_5_1_model_5_1_mae: 0.0906 - val_model_5_1_model_5_1_model_5_1_acc: 0.9128 - val_output_layer_output_layer_output_layer_mae: 1.0590 - val_output_layer_output_layer_output_layer_acc: 0.0525
# Epoch 126/140
# 30/30 [==============================] - 306s 10s/step - loss: 0.2668 - model_5_loss: 0.0520 - model_5_1_loss: 0.1630 - output_layer_loss: 0.0088 - model_5_model_5_model_5_mae: 0.0357 - model_5_model_5_model_5_acc: 0.9766 - model_5_1_model_5_1_model_5_1_mae: 0.0883 - model_5_1_model_5_1_model_5_1_acc: 0.9220 - output_layer_output_layer_output_layer_mae: 1.2091 - output_layer_output_layer_output_layer_acc: 0.0000e+00 - val_loss: 0.4551 - val_model_5_loss: 0.0694 - val_model_5_1_loss: 0.2921 - val_output_layer_loss: 0.0506 - val_model_5_model_5_model_5_mae: 0.0402 - val_model_5_model_5_model_5_acc: 0.9672 - val_model_5_1_model_5_1_model_5_1_mae: 0.0990 - val_model_5_1_model_5_1_model_5_1_acc: 0.9073 - val_output_layer_output_layer_output_layer_mae: 1.0259 - val_output_layer_output_layer_output_layer_acc: 0.0600
# Epoch 127/140
# 30/30 [==============================] - 309s 10s/step - loss: 0.2704 - model_5_loss: 0.0543 - model_5_1_loss: 0.1636 - output_layer_loss: 0.0095 - model_5_model_5_model_5_mae: 0.0368 - model_5_model_5_model_5_acc: 0.9755 - model_5_1_model_5_1_model_5_1_mae: 0.0898 - model_5_1_model_5_1_model_5_1_acc: 0.9215 - output_layer_output_layer_output_layer_mae: 1.1769 - output_layer_output_layer_output_layer_acc: 0.0021 - val_loss: 0.3842 - val_model_5_loss: 0.0709 - val_model_5_1_loss: 0.2314 - val_output_layer_loss: 0.0388 - val_model_5_model_5_model_5_mae: 0.0455 - val_model_5_model_5_model_5_acc: 0.9694 - val_model_5_1_model_5_1_model_5_1_mae: 0.1018 - val_model_5_1_model_5_1_model_5_1_acc: 0.9137 - val_output_layer_output_layer_output_layer_mae: 1.1123 - val_output_layer_output_layer_output_layer_acc: 0.0325
# Epoch 128/140
# 30/30 [==============================] - 307s 10s/step - loss: 0.2624 - model_5_loss: 0.0515 - model_5_1_loss: 0.1550 - output_layer_loss: 0.0126 - model_5_model_5_model_5_mae: 0.0349 - model_5_model_5_model_5_acc: 0.9764 - model_5_1_model_5_1_model_5_1_mae: 0.0830 - model_5_1_model_5_1_model_5_1_acc: 0.9270 - output_layer_output_layer_output_layer_mae: 1.1535 - output_layer_output_layer_output_layer_acc: 0.0063 - val_loss: 0.4027 - val_model_5_loss: 0.0686 - val_model_5_1_loss: 0.2391 - val_output_layer_loss: 0.0515 - val_model_5_model_5_model_5_mae: 0.0463 - val_model_5_model_5_model_5_acc: 0.9708 - val_model_5_1_model_5_1_model_5_1_mae: 0.1029 - val_model_5_1_model_5_1_model_5_1_acc: 0.9126 - val_output_layer_output_layer_output_layer_mae: 1.0262 - val_output_layer_output_layer_output_layer_acc: 0.0525
# Epoch 129/140
# 30/30 [==============================] - 307s 10s/step - loss: 0.2660 - model_5_loss: 0.0532 - model_5_1_loss: 0.1588 - output_layer_loss: 0.0105 - model_5_model_5_model_5_mae: 0.0362 - model_5_model_5_model_5_acc: 0.9758 - model_5_1_model_5_1_model_5_1_mae: 0.0876 - model_5_1_model_5_1_model_5_1_acc: 0.9213 - output_layer_output_layer_output_layer_mae: 1.1395 - output_layer_output_layer_output_layer_acc: 0.0000e+00 - val_loss: 0.4083 - val_model_5_loss: 0.0609 - val_model_5_1_loss: 0.2475 - val_output_layer_loss: 0.0566 - val_model_5_model_5_model_5_mae: 0.0388 - val_model_5_model_5_model_5_acc: 0.9714 - val_model_5_1_model_5_1_model_5_1_mae: 0.0933 - val_model_5_1_model_5_1_model_5_1_acc: 0.9160 - val_output_layer_output_layer_output_layer_mae: 0.9812 - val_output_layer_output_layer_output_layer_acc: 0.0700
# Epoch 130/140
# 30/30 [==============================] - 306s 10s/step - loss: 0.2549 - model_5_loss: 0.0512 - model_5_1_loss: 0.1520 - output_layer_loss: 0.0085 - model_5_model_5_model_5_mae: 0.0347 - model_5_model_5_model_5_acc: 0.9764 - model_5_1_model_5_1_model_5_1_mae: 0.0842 - model_5_1_model_5_1_model_5_1_acc: 0.9245 - output_layer_output_layer_output_layer_mae: 1.1484 - output_layer_output_layer_output_layer_acc: 0.0000e+00 - val_loss: 0.3994 - val_model_5_loss: 0.0595 - val_model_5_1_loss: 0.2394 - val_output_layer_loss: 0.0575 - val_model_5_model_5_model_5_mae: 0.0377 - val_model_5_model_5_model_5_acc: 0.9718 - val_model_5_1_model_5_1_model_5_1_mae: 0.0905 - val_model_5_1_model_5_1_model_5_1_acc: 0.9192 - val_output_layer_output_layer_output_layer_mae: 1.1107 - val_output_layer_output_layer_output_layer_acc: 0.0625
# Epoch 131/140
# 30/30 [==============================] - 306s 10s/step - loss: 0.2584 - model_5_loss: 0.0530 - model_5_1_loss: 0.1554 - output_layer_loss: 0.0072 - model_5_model_5_model_5_mae: 0.0358 - model_5_model_5_model_5_acc: 0.9760 - model_5_1_model_5_1_model_5_1_mae: 0.0855 - model_5_1_model_5_1_model_5_1_acc: 0.9246 - output_layer_output_layer_output_layer_mae: 1.1573 - output_layer_output_layer_output_layer_acc: 0.0000e+00 - val_loss: 0.4276 - val_model_5_loss: 0.0646 - val_model_5_1_loss: 0.2592 - val_output_layer_loss: 0.0613 - val_model_5_model_5_model_5_mae: 0.0403 - val_model_5_model_5_model_5_acc: 0.9694 - val_model_5_1_model_5_1_model_5_1_mae: 0.0996 - val_model_5_1_model_5_1_model_5_1_acc: 0.9102 - val_output_layer_output_layer_output_layer_mae: 1.0505 - val_output_layer_output_layer_output_layer_acc: 0.0900
# Epoch 132/140
# 30/30 [==============================] - 306s 10s/step - loss: 0.2501 - model_5_loss: 0.0507 - model_5_1_loss: 0.1502 - output_layer_loss: 0.0067 - model_5_model_5_model_5_mae: 0.0335 - model_5_model_5_model_5_acc: 0.9762 - model_5_1_model_5_1_model_5_1_mae: 0.0814 - model_5_1_model_5_1_model_5_1_acc: 0.9279 - output_layer_output_layer_output_layer_mae: 1.1524 - output_layer_output_layer_output_layer_acc: 0.0000e+00 - val_loss: 0.3919 - val_model_5_loss: 0.0627 - val_model_5_1_loss: 0.2366 - val_output_layer_loss: 0.0503 - val_model_5_model_5_model_5_mae: 0.0390 - val_model_5_model_5_model_5_acc: 0.9705 - val_model_5_1_model_5_1_model_5_1_mae: 0.0927 - val_model_5_1_model_5_1_model_5_1_acc: 0.9171 - val_output_layer_output_layer_output_layer_mae: 1.0735 - val_output_layer_output_layer_output_layer_acc: 0.0650
# Epoch 133/140
# 30/30 [==============================] - 306s 10s/step - loss: 0.2607 - model_5_loss: 0.0540 - model_5_1_loss: 0.1576 - output_layer_loss: 0.0069 - model_5_model_5_model_5_mae: 0.0369 - model_5_model_5_model_5_acc: 0.9758 - model_5_1_model_5_1_model_5_1_mae: 0.0882 - model_5_1_model_5_1_model_5_1_acc: 0.9224 - output_layer_output_layer_output_layer_mae: 1.1773 - output_layer_output_layer_output_layer_acc: 0.0021 - val_loss: 0.3967 - val_model_5_loss: 0.0680 - val_model_5_1_loss: 0.2414 - val_output_layer_loss: 0.0453 - val_model_5_model_5_model_5_mae: 0.0416 - val_model_5_model_5_model_5_acc: 0.9690 - val_model_5_1_model_5_1_model_5_1_mae: 0.0970 - val_model_5_1_model_5_1_model_5_1_acc: 0.9138 - val_output_layer_output_layer_output_layer_mae: 1.0759 - val_output_layer_output_layer_output_layer_acc: 0.0425
# Epoch 134/140
# 30/30 [==============================] - 306s 10s/step - loss: 0.2679 - model_5_loss: 0.0547 - model_5_1_loss: 0.1626 - output_layer_loss: 0.0087 - model_5_model_5_model_5_mae: 0.0370 - model_5_model_5_model_5_acc: 0.9755 - model_5_1_model_5_1_model_5_1_mae: 0.0895 - model_5_1_model_5_1_model_5_1_acc: 0.9208 - output_layer_output_layer_output_layer_mae: 1.1614 - output_layer_output_layer_output_layer_acc: 0.0021 - val_loss: 0.3905 - val_model_5_loss: 0.0671 - val_model_5_1_loss: 0.2204 - val_output_layer_loss: 0.0611 - val_model_5_model_5_model_5_mae: 0.0449 - val_model_5_model_5_model_5_acc: 0.9706 - val_model_5_1_model_5_1_model_5_1_mae: 0.0990 - val_model_5_1_model_5_1_model_5_1_acc: 0.9166 - val_output_layer_output_layer_output_layer_mae: 0.9984 - val_output_layer_output_layer_output_layer_acc: 0.0725
# Epoch 135/140
# 30/30 [==============================] - 305s 10s/step - loss: 0.2664 - model_5_loss: 0.0536 - model_5_1_loss: 0.1612 - output_layer_loss: 0.0095 - model_5_model_5_model_5_mae: 0.0370 - model_5_model_5_model_5_acc: 0.9763 - model_5_1_model_5_1_model_5_1_mae: 0.0890 - model_5_1_model_5_1_model_5_1_acc: 0.9211 - output_layer_output_layer_output_layer_mae: 1.1631 - output_layer_output_layer_output_layer_acc: 0.0000e+00 - val_loss: 0.4012 - val_model_5_loss: 0.0666 - val_model_5_1_loss: 0.2465 - val_output_layer_loss: 0.0459 - val_model_5_model_5_model_5_mae: 0.0401 - val_model_5_model_5_model_5_acc: 0.9703 - val_model_5_1_model_5_1_model_5_1_mae: 0.0994 - val_model_5_1_model_5_1_model_5_1_acc: 0.9123 - val_output_layer_output_layer_output_layer_mae: 1.0733 - val_output_layer_output_layer_output_layer_acc: 0.0500
# Epoch 136/140
# 30/30 [==============================] - 305s 10s/step - loss: 0.2655 - model_5_loss: 0.0544 - model_5_1_loss: 0.1580 - output_layer_loss: 0.0109 - model_5_model_5_model_5_mae: 0.0367 - model_5_model_5_model_5_acc: 0.9754 - model_5_1_model_5_1_model_5_1_mae: 0.0869 - model_5_1_model_5_1_model_5_1_acc: 0.9232 - output_layer_output_layer_output_layer_mae: 1.1610 - output_layer_output_layer_output_layer_acc: 0.0021 - val_loss: 0.3956 - val_model_5_loss: 0.0739 - val_model_5_1_loss: 0.2372 - val_output_layer_loss: 0.0420 - val_model_5_model_5_model_5_mae: 0.0463 - val_model_5_model_5_model_5_acc: 0.9694 - val_model_5_1_model_5_1_model_5_1_mae: 0.1001 - val_model_5_1_model_5_1_model_5_1_acc: 0.9141 - val_output_layer_output_layer_output_layer_mae: 1.0485 - val_output_layer_output_layer_output_layer_acc: 0.0300
# Epoch 137/140
# 30/30 [==============================] - 306s 10s/step - loss: 0.2682 - model_5_loss: 0.0532 - model_5_1_loss: 0.1563 - output_layer_loss: 0.0162 - model_5_model_5_model_5_mae: 0.0362 - model_5_model_5_model_5_acc: 0.9758 - model_5_1_model_5_1_model_5_1_mae: 0.0867 - model_5_1_model_5_1_model_5_1_acc: 0.9242 - output_layer_output_layer_output_layer_mae: 1.1140 - output_layer_output_layer_output_layer_acc: 0.0021 - val_loss: 0.4525 - val_model_5_loss: 0.0587 - val_model_5_1_loss: 0.2940 - val_output_layer_loss: 0.0568 - val_model_5_model_5_model_5_mae: 0.0339 - val_model_5_model_5_model_5_acc: 0.9703 - val_model_5_1_model_5_1_model_5_1_mae: 0.0908 - val_model_5_1_model_5_1_model_5_1_acc: 0.9128 - val_output_layer_output_layer_output_layer_mae: 1.0503 - val_output_layer_output_layer_output_layer_acc: 0.0550
# Epoch 138/140
# 30/30 [==============================] - 308s 10s/step - loss: 0.2725 - model_5_loss: 0.0532 - model_5_1_loss: 0.1612 - output_layer_loss: 0.0147 - model_5_model_5_model_5_mae: 0.0361 - model_5_model_5_model_5_acc: 0.9761 - model_5_1_model_5_1_model_5_1_mae: 0.0885 - model_5_1_model_5_1_model_5_1_acc: 0.9229 - output_layer_output_layer_output_layer_mae: 1.1579 - output_layer_output_layer_output_layer_acc: 0.0042 - val_loss: 0.4016 - val_model_5_loss: 0.0593 - val_model_5_1_loss: 0.2512 - val_output_layer_loss: 0.0474 - val_model_5_model_5_model_5_mae: 0.0372 - val_model_5_model_5_model_5_acc: 0.9719 - val_model_5_1_model_5_1_model_5_1_mae: 0.0905 - val_model_5_1_model_5_1_model_5_1_acc: 0.9173 - val_output_layer_output_layer_output_layer_mae: 1.0143 - val_output_layer_output_layer_output_layer_acc: 0.0400
# Epoch 139/140
# 30/30 [==============================] - 308s 10s/step - loss: 0.2645 - model_5_loss: 0.0522 - model_5_1_loss: 0.1567 - output_layer_loss: 0.0117 - model_5_model_5_model_5_mae: 0.0349 - model_5_model_5_model_5_acc: 0.9758 - model_5_1_model_5_1_model_5_1_mae: 0.0872 - model_5_1_model_5_1_model_5_1_acc: 0.9233 - output_layer_output_layer_output_layer_mae: 1.1593 - output_layer_output_layer_output_layer_acc: 0.0000e+00 - val_loss: 0.4048 - val_model_5_loss: 0.0649 - val_model_5_1_loss: 0.2437 - val_output_layer_loss: 0.0524 - val_model_5_model_5_model_5_mae: 0.0418 - val_model_5_model_5_model_5_acc: 0.9705 - val_model_5_1_model_5_1_model_5_1_mae: 0.0955 - val_model_5_1_model_5_1_model_5_1_acc: 0.9163 - val_output_layer_output_layer_output_layer_mae: 1.0064 - val_output_layer_output_layer_output_layer_acc: 0.0475
# Epoch 140/140
# 30/30 [==============================] - 306s 10s/step - loss: 0.2587 - model_5_loss: 0.0508 - model_5_1_loss: 0.1544 - output_layer_loss: 0.0100 - model_5_model_5_model_5_mae: 0.0346 - model_5_model_5_model_5_acc: 0.9766 - model_5_1_model_5_1_model_5_1_mae: 0.0850 - model_5_1_model_5_1_model_5_1_acc: 0.9250 - output_layer_output_layer_output_layer_mae: 1.1353 - output_layer_output_layer_output_layer_acc: 0.0000e+00 - val_loss: 0.4248 - val_model_5_loss: 0.0656 - val_model_5_1_loss: 0.2654 - val_output_layer_loss: 0.0505 - val_model_5_model_5_model_5_mae: 0.0399 - val_model_5_model_5_model_5_acc: 0.9695 - val_model_5_1_model_5_1_model_5_1_mae: 0.0961 - val_model_5_1_model_5_1_model_5_1_acc: 0.9133 - val_output_layer_output_layer_output_layer_mae: 1.0408 - val_output_layer_output_layer_output_layer_acc: 0.0650

# %%
import matplotlib.pyplot as plt
# Let's take a look at how we did during training.
acc = history.history['model_5_model_5_model_5_acc']
val_acc = history.history['val_model_5_model_5_model_5_acc']

loss = history.history['model_5_1_loss']
val_loss = history.history['val_model_5_1_loss']
epochs = range(len(acc))

# Accuracy
fig, ax = plt.subplots(1, 2, figsize=(30, 10))
ax[0].plot(epochs, acc, 'r', label='Training accuracy')
ax[0].plot(epochs, val_acc, 'b', label='Validation accuracy')
ax[0].set_title('Training and validation accuracy')
ax[0].legend()

# Loss
ax[1].plot(epochs, loss, 'r', label='Training Loss')
ax[1].plot(epochs, val_loss, 'b', label='Validation Loss')
ax[1].set_title('Training and validation loss')
ax[1].legend()

plt.show()

# %%
model_save_path = '/tensorflow/siamese_model/siamese_unet_pixel_half_seg_rotation_300epoch_120_train_test.h5'
model.save(model_save_path)

# %%
model = load_model(model_save_path,custom_objects={'contrastive_loss':contrastive_loss_with_margin(margin=1)})

# %%
Out = next((imageLoader(path_input_images,folder_name_list_test,mask_path,1)))

# %%
images_L_R = Out[0]
image_L = images_L_R[0]
image_R = images_L_R[1]

mask_L_R_class = Out[1]

mask_L = mask_L_R_class[0]
mask_R = mask_L_R_class[1]
y = mask_L_R_class[2]
print(y[0])
print(image_L.shape)
#plt.title('left_mask')
#plt.imshow(np.squeeze(mask_R[1]))
#plt.imshow(image_R[1])
#plt.show()
# Out:
# 1.0
# (4, 128, 128, 1)

# %%
preds = model.predict([image_L,image_R])

# %%
#plt.imshow(np.squeeze(mask_R[1]))
plt.imshow(image_R[1],cmap='gray')
plt.show()

# %%
out_image = np.squeeze(preds[1][1])
preds[0].shape
# Out:
# (4, 128, 128, 1)

# %%
dummy_image = image_R[1].copy() 
dummy_image[out_image<.5] = 0
plt.imshow(dummy_image,cmap='gray')
plt.show()

# %%
y = preds[2]
print(y)
# Out:
# [[0.2058212 ]
#  [0.14926901]
#  [1.0851554 ]
#  [1.3595473 ]]

# %% [markdown]
# ## Test data for model

# %%
test_out1,test_out2,test_seg1,test_seg2,y_class = read_simaese_parametric_data(path_input_images,folder_name_list[0:100],mask_path,100)

# %%
test_out1 = test_out1/255.0
test_out2 = test_out2/255.0
# test_seg1 = test_seg1/255.0
# test_seg2 = test_seg2/255.0

# %%
[test_seg_out1,test_seg_out2, y_pred] = model.predict([test_out1,test_out2])

# %%
test_seg2.shape
# Out:
# (400, 128, 128, 1)

# %%
def show_images(test_out1,test_seg_out1):
    #num_images = len(test_seg_out1)
    num_images = 20
    for i in range(0,num_images,4):
        dummy_image = np.squeeze(test_out1[i]).copy()
        seg_img = np.squeeze(test_seg_out1[i])
        dummy_image[seg_img<.5] = 0
        plt.imshow(np.squeeze(test_out1[i]),cmap='gray')
        plt.show()
        plt.imshow(dummy_image,cmap='gray')
        plt.show()

# %%
show_images(test_out2,test_seg_out2)

# %%
def compute_accuracy(y_true, y_pred):
    '''Compute classification accuracy with a fixed threshold on distances.
    '''
    pred = y_pred.ravel() < 0.5
    return np.mean(pred == y_true)

# %%
compute_accuracy(y_class, y_pred)      ## trained on 120 images and tested on 100 persons
# Out:
# 1.0

# %%
# !{sys.executable} -m pip install -U scikit-learn scipy
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (0.24.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (1.5.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.0.1)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_class, y_pred.ravel() < 0.5)                      ##   [TN , FP]
                                                                     ##     [FN , TP]
# Out:
# array([[200,   0],
#        [  0, 200]])

# %%
def rotate_image_tensor(image, angle, mode='black'):
    """
    Rotates a 3D tensor (HWD), which represents an image by given radian angle.

    New image has the same size as the input image.

    mode controls what happens to border pixels.
    mode = 'black' results in black bars (value 0 in unknown areas)
    mode = 'white' results in value 255 in unknown areas
    mode = 'ones' results in value 1 in unknown areas
    mode = 'repeat' keeps repeating the closest pixel known
    """
    s = image.get_shape().as_list()
    assert len(s) == 3, "Input needs to be 3D."
    assert (mode == 'repeat') or (mode == 'black') or (mode == 'white') or (mode == 'ones'), "Unknown boundary mode."
    image_center = [np.floor(x/2) for x in s]

    # Coordinates of new image
    coord1 = tf.range(s[0])
    coord2 = tf.range(s[1])

    # Create vectors of those coordinates in order to vectorize the image
    coord1_vec = tf.tile(coord1, [s[1]])

    coord2_vec_unordered = tf.tile(coord2, [s[0]])
    coord2_vec_unordered = tf.reshape(coord2_vec_unordered, [s[0], s[1]])
    coord2_vec = tf.reshape(tf.transpose(coord2_vec_unordered, [1, 0]), [-1])

    # center coordinates since rotation center is supposed to be in the image center
    coord1_vec_centered = coord1_vec - image_center[0]
    coord2_vec_centered = coord2_vec - image_center[1]

    coord_new_centered = tf.cast(tf.pack([coord1_vec_centered, coord2_vec_centered]), tf.float32)

# %%
  image = tf.constant(np.zeros((384, 512, 5)), dtype = tf.float32)
  image = tfa.image.rotate(image, tf.random.uniform(shape = [], minval = -0.3, maxval = 0.3))

# %%
tf.random.uniform(shape = [], minval = -0.3, maxval = 0.3)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.07962942>

# %%
tf.constant(0,dtype='float32')
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.0>

# %%
128*5 # (2*np.pi/360)*
# Out:
# 640

# %%
c = tf.constant([1.0, 2.0, 3.0, 4.0])          #2x4 
d = tf.constant([3.0, 4.0, 1.0,2.0])

# %%
print(concatenate([c,d],axis=0)[0:4])
# Out:
# tf.Tensor([1. 2. 3. 4.], shape=(4,), dtype=float32)

# %%
# a = tf.squeeze(tf.constant(np.zeros((None,512)),dtype=tf.float32))
a = tf.zeros([None, 4], tf.float32)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py in zeros(shape, dtype, name)
#    2873         shape = constant_op._tensor_shape_tensor_conversion_function(
# -> 2874             tensor_shape.TensorShape(shape))
#    2875       except (TypeError, ValueError):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in _tensor_shape_tensor_conversion_function(s, dtype, name, as_ref)
#     355     raise ValueError(
# --> 356         "Cannot convert a partially known TensorShape to a Tensor: %s" % s)
#     357   s_list = s.as_list()
#
# ValueError: Cannot convert a partially known TensorShape to a Tensor: (None, 4)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-e56ad6eb3c6b> in <module>
#       1 # a = tf.squeeze(tf.constant(np.zeros((None,512)),dtype=tf.float32))
# ----> 2 a = tf.zeros([None, 4], tf.float32)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py in wrapped(*args, **kwargs)
#    2817
#    2818   def wrapped(*args, **kwargs):
# -> 2819     tensor = fun(*args, **kwargs)
#    2820     tensor._is_zeros_tensor = True
#    2821     return tensor
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py in zeros(shape, dtype, name)
#    2875       except (TypeError, ValueError):
#    2876         # Happens when shape is a list with tensor elements
# -> 2877         shape = ops.convert_to_tensor(shape, dtype=dtypes.int32)
#    2878     if not shape._shape_tuple():
#    2879       shape = reshape(shape, [-1])  # Ensure it's a vector
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1538
#    1539     if ret is None:
# -> 1540       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1541
#    1542     if ret is NotImplemented:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     337                                          as_ref=False):
#     338   _ = as_ref
# --> 339   return constant(v, dtype=dtype, name=name)
#     340
#     341
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     263   """
#     264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 265                         allow_broadcast=True)
#     266
#     267
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     274       with trace.Trace("tf.constant"):
#     275         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 276     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277
#     278   g = ops.get_default_graph()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     299 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     300   """Implementation of eager constant."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# ValueError: Attempt to convert a value (None) with an unsupported type (<class 'NoneType'>) to a Tensor.

# %%
a
