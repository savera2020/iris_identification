# %%
# import cv2 
# import numpy as np
# import glob
# import os
# from itertools import combinations 
# from itertools import product
# import random
# import matplotlib.pyplot as plt
# from random import randrange
# import sys
# import math
#apt install python-pydot python-pydot-ng graphviz

# %%
import cv2 
import numpy as np
import glob
import os
from itertools import combinations 
from itertools import product
import random
import matplotlib.pyplot as plt
from random import randrange
import sys
import math
import pandas as pd
#apt install python-pydot python-pydot-ng graphviz

# %%
# !{sys.executable} -m pip install pydot
# !{sys.executable} -m pip install pydotplus
# !{sys.executable} -m pip install graphviz
# !{sys.executable} -m pip install xlrd==1.2.0
# Out:
# Requirement already satisfied: pydot in /usr/local/lib/python3.6/dist-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.6/dist-packages (from pydot) (2.4.7)
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.6/dist-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from pydotplus) (2.4.7)
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: graphviz in /usr/local/lib/python3.6/dist-packages (0.16)
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: xlrd==1.2.0 in /usr/local/lib/python3.6/dist-packages (1.2.0)
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import tensorflow as tf 
from tensorflow.keras.layers import Dense, MaxPooling2D, Convolution2D, Dropout, Input, Flatten,Conv2D,Conv2DTranspose,Lambda,concatenate,GlobalMaxPooling2D,Activation
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model,Sequential
#from keras.initializers.h as 
from tensorflow.python.keras.utils.vis_utils import plot_model
from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#from tensorflow.python.keras.utils.vis_utils import plot_model
from tensorflow.keras.models import load_model
from tensorflow.keras.regularizers import l2 
from pandas import read_excel
import pydot
# !{sys.executable} -m pip install tensorflow-addons
import tensorflow_addons as tfa
from pandas import read_excel
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.6/dist-packages (0.13.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons) (2.12.1)
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
path_input_images = '/tensorflow/Casia_V1/'

# %%
#mask_path  = '/tensorflow/iit_unet/mask_data/'
#data_in_labels_path  = '/tensorflow/accurate_iitd.csv'

# %%
#data = read_excel(data_in_labels_path, sheet_name='Sheet1')

#data = pd.read_csv(data_in_labels_path)

# %%
#data.head()

# %%
# hist_p  = np.histogram(data['R1p'])
# hist_s = np.histogram(data['R1s'])

# hist_p[0].shape
# plt.plot(hist_p[0])
# # plt.show()
#print(np.max(data['Y1p']))
#hist_s = np.histogram(data['Y1s'],255)
#print(np.max(data['Y1s']))

# %%
def generate_mask():
    mask_img = np.zeros((280,320,3),dtype='uint8')
    generate_r  = randrange(35,55)

    generate_s  = randrange(generate_r+60,115)


    center = (160,140)
    
    ## outer circle
    mask1 = cv2.circle(mask_img, center, generate_s,(255,255,255),-1)
    ## inner circle 
    mask2 = cv2.circle(mask1, center, generate_r,(0,0,0),-1)

    return mask2

mask2 = generate_mask()
plt.imshow(mask2)
plt.show()

# %%
# img_path = '/tensorflow/IITD_Database/001/01.bmp'
# img = cv2.imread(img_path)

def translate_to_center(img):

    ret2,th2 = cv2.threshold(img[:,:,0],60,255,cv2.THRESH_BINARY)

    [h,w] = th2.shape

    col_list = []
    row_list = []

    #find the gravity of image
    for i in range(h):

        for j in range(w):

            if(th2[i,j]==0):

                col_list.append(j)
                row_list.append(i)

    center_col = round(np.mean(col_list))
    center_row = round(np.mean(row_list))

    T_col = round(w/2 - round(np.mean(col_list)))
    T_row = round(h/2 - round(np.mean(row_list)))


    T = np.float32([[1, 0, T_col], [0, 1, T_row]])

    # We use warpAffine to transform
    # the image using the matrix, T
    img_translation = cv2.warpAffine(img, T, (w, h))
    
    return img_translation



#print(center_col,center_row)
img_path = '/tensorflow/Casia_V1/001/1/001_1_1.bmp'
img = cv2.imread(img_path)
img_translation = translate_to_center(img)
plt.imshow(img_translation,cmap='gray')
plt.show()

# %%
folder_name1 = str(randrange(0,100)).zfill(3) 
print(folder_name1)
# Out:
# 095

# %%
def change_name(name):
    d = name.split('/')
    mask_name = 'frame' + '_' + d[0]+'_'+d[1] +'.png'
    return mask_name

# %%
#rows = data[data['image_name']=='001_04.bmp']

# %%
#rows['Y1p'].iloc[0]

# %%
def read_simaese_parametric_data(path_input_images, folder_name_list_batch,batch_size):
    
    
    h  = 128
    w = 128 
    c = 1
    factor  = 4
    
    train_out1 = np.zeros((factor*batch_size,h,w,c),'float')
    train_out2 = np.zeros((factor*batch_size,h,w,c),'float')
    train_seg1 = np.zeros((factor*batch_size,h,w,1),'float')
    train_seg2 = np.zeros((factor*batch_size,h,w,1),'float')
    
    out1= np.zeros((factor*batch_size,h,w,c),'float')
    out2= np.zeros((factor*batch_size,h,w,c),'float')
    
    seg1= np.zeros((factor*batch_size,h,w,1),'float')
    seg2= np.zeros((factor*batch_size,h,w,1),'float')
    
    #pos_comb1 = np.array(list(combinations([1, 2, 3, 4, 5], 2)))
    pos_comb1 = np.array(list(combinations([1, 2, 3], 2)))
    #
    count = 0
    y = []
    left = '1'
    right = '2'
    for folder_name in folder_name_list_batch:

        for j in range (len(pos_comb1)-2):
           
            i = random.randint(0, 2)
        
            ## read the image from folder in postive combination 
            #print('pos_combi =' + folder_name + '/'+ str(pos_comb1[i][0]).zfill(2)+'.bmp')
            #img1_0 = cv2.imread(path_input_images + folder_name + '/'+ str(pos_comb1[i][0]).zfill(2)+'.bmp')
            img1_0 = cv2.imread(path_input_images + folder_name +'/'+left +'/'+ str(folder_name+'_'+left+'_'+str(pos_comb1[i][0]))+'.bmp')
            img1_0 = translate_to_center(img1_0)
            
            #img1_1 = cv2.imread(path_input_images + folder_name + '/'+ str(pos_comb1[i][1]).zfill(2)+'.bmp')
            img1_1 = cv2.imread(path_input_images + folder_name + '/'+left +'/'+ str(folder_name+'_'+left+'_'+str(pos_comb1[i][1]))+'.bmp')
#             print('pos_combi =' + folder_name + '/'+ str(pos_comb1[i][1]).zfill(2)+'.bmp')
            img1_1 = translate_to_center(img1_1)
    
            img1_0 = cv2.resize(img1_0[:,:,0],(h,w))    #c = 1
            img1_1 = cv2.resize(img1_1[:,:,0],(h,w))
            ##get the correspondance segmentation data 
#             name1 = folder_name + '/'+ str(pos_comb1[i][0]).zfill(2)
#             name2 = folder_name + '/'+ str(pos_comb1[i][1]).zfill(2)
            seg1_0 = generate_mask()
            seg1_1 = generate_mask()
            ###############################################################
            seg1_0 = cv2.cvtColor(seg1_0,cv2.COLOR_BGR2GRAY)
            seg1_1 = cv2.cvtColor(seg1_1,cv2.COLOR_BGR2GRAY)
            
            seg1_0 = cv2.resize(seg1_0,(h,w))
            seg1_1 = cv2.resize(seg1_1,(h,w))
            
            ## save the image data to out and out2         
            out1[count]  = np.expand_dims(img1_0,axis=2) #img1_0
            out2[count]  = np.expand_dims(img1_1,axis=2) #img1_1
            seg1[count]  = np.expand_dims(seg1_0,axis=2)
            seg2[count]  = np.expand_dims(seg1_1,axis=2)
            
            #save the segmentation data to lable 

            
            ## posive combination assigning 0 to last clolumn
            y.append(1.0)
            
            ## increament the count
            count = count+1
            
            

#             img2_0 = cv2.imread(path_input_images + folder_name + '/'+ str(pos_comb2[i][0]).zfill(2)+'.bmp')
#             img2_1 = cv2.imread(path_input_images + folder_name + '/'+ str(pos_comb2[i][1]).zfill(2)+'.bmp')
            
    
    
            img2_0 = cv2.imread(path_input_images + folder_name + '/'+ right + '/'+ str(folder_name+'_'+right+'_'+str(pos_comb1[i][0]))+'.bmp')
            img2_1 = cv2.imread(path_input_images + folder_name + '/'+ right + '/'+ str(folder_name+'_'+right+'_'+str(pos_comb1[i][1]))+'.bmp')
            img2_0 = translate_to_center(img2_0)
            img2_1 = translate_to_center(img2_1)
            
            img2_0 = cv2.resize(img2_0[:,:,0],(h,w)) ## C = 1
            img2_1 = cv2.resize(img2_1[:,:,0],(h,w))  ## c = 1
            
#             name1 = folder_name + '/'+ str(pos_comb2[i][0]).zfill(2)
#             name2 = folder_name + '/'+ str(pos_comb2[i][1]).zfill(2)
            seg2_0 = generate_mask()
            seg2_1 = generate_mask()
            
            seg2_0 = cv2.cvtColor(seg2_0,cv2.COLOR_BGR2GRAY)
            seg2_1 = cv2.cvtColor(seg2_1,cv2.COLOR_BGR2GRAY)
            seg2_0 = cv2.resize(seg2_0,(h,w))
            seg2_1 = cv2.resize(seg2_1,(h,w))
            out1[count]  = np.expand_dims(img2_0,axis=2)#img2_0
            out2[count]  = np.expand_dims(img2_1,axis=2)#img2_1
            seg1[count]  = np.expand_dims(seg2_0,axis=2)
            seg2[count]  = np.expand_dims(seg2_1,axis=2)          

            y.append(1.0)
            count = count+1

            
            ## negative combination left vs right iris for same person 
            #folder_name2 = str(int(folder_name) + 1).zfill(3)
#             print('neg_combi =' + folder_name2 + '/'+ str(neg_comb1[i][1]).zfill(2)+'.bmp')
#             print('neg_combi =' + folder_name + '/'+ str(neg_comb1[i][0]).zfill(2)+'.bmp')
#             img3_0 = cv2.imread(path_input_images + folder_name + '/'+ str(neg_comb1[i][0]).zfill(2)+'.bmp')
#             img3_1 = cv2.imread(path_input_images + folder_name2 + '/'+ str(neg_comb1[i][1]).zfill(2)+'.bmp')
            
            img3_0 = cv2.imread(path_input_images + folder_name + '/'+ left + '/'+ str(folder_name+'_'+left+'_'+str(pos_comb1[i][0]))+'.bmp')
            img3_1 = cv2.imread(path_input_images + folder_name + '/'+ right + '/'+ str(folder_name+'_'+right+'_'+str(pos_comb1[i][1]))+'.bmp')
            img3_0 = translate_to_center(img3_0)
            img3_1 = translate_to_center(img3_1)
            img3_0 = cv2.resize(img3_0[:,:,0],(h,w))  #c = 1
            img3_1 = cv2.resize(img3_1[:,:,0],(h,w))
            
#             name1 = folder_name + '/'+ str(neg_comb1[i][0]).zfill(2)
#             name2 = folder_name + '/'+ str(neg_comb1[i][1]).zfill(2)
            seg3_0 = generate_mask()
            seg3_1 = generate_mask()
            
            seg3_0 = cv2.cvtColor(seg3_0,cv2.COLOR_BGR2GRAY)
            seg3_1 = cv2.cvtColor(seg3_1,cv2.COLOR_BGR2GRAY)
            
            seg3_0 = cv2.resize(seg3_0,(h,w))
            seg3_1 = cv2.resize(seg3_1,(h,w))
            
            out1[count]  = np.expand_dims(img3_0,axis=2) #img3_0
            out2[count]  = np.expand_dims(img3_1,axis=2) #img3_1
            seg1[count]  = np.expand_dims(seg3_0,axis=2)
            seg2[count]  = np.expand_dims(seg3_1,axis=2)
            ## assigning 1 to negative combinations (left vs right image)
            y.append(0.0)
            count = count+1

            
            ## creating the negativ combination from diffrent person 
            
            folder_name1 = str(randrange(1,100)).zfill(3) 
            
            left_right = str(randrange(1,2)) 
            
            if(folder_name1==folder_name):

                folder_name1 = str(int(folder_name) - 1).zfill(3) 
                
                
#             img4_0 = cv2.imread(path_input_images + folder_name + '/'+ str(pos_comb1[i][0]).zfill(2)+'.bmp')
#             img4_1 = cv2.imread(path_input_images + folder_name1 + '/'+ str(pos_comb1[i][1]).zfill(2)+'.bmp')
            img4_0 = cv2.imread(path_input_images + folder_name + '/'+ left_right+ '/'+ str(folder_name+'_'+left_right+'_'+str(pos_comb1[i][0]))+'.bmp')
            img4_1 = cv2.imread(path_input_images + folder_name1 + '/'+ left_right+ '/'+ str(folder_name1+'_'+left_right+'_'+str(pos_comb1[i][0]))+'.bmp')
            img4_0 = translate_to_center(img4_0)
            img4_1 = translate_to_center(img4_1)
            
            img4_0 = cv2.resize(img4_0[:,:,0],(h,w))
            img4_1 = cv2.resize(img4_1[:,:,0],(h,w))
#             name1 = folder_name + '/'+ str(pos_comb1[i][0]).zfill(2)
#             name2 = folder_name1 + '/'+ str(pos_comb1[i][1]).zfill(2)
            seg4_0 = generate_mask()
            seg4_1 = generate_mask()

            seg4_0 = cv2.cvtColor(seg4_0,cv2.COLOR_BGR2GRAY)
            seg4_1 = cv2.cvtColor(seg4_1,cv2.COLOR_BGR2GRAY)        

            seg4_0 = cv2.resize(seg4_0,(h,w))
            seg4_1 = cv2.resize(seg4_1,(h,w))
            
            out1[count]  = np.expand_dims(img4_0,axis=2)#img4_0
            out2[count]  = np.expand_dims(img4_1,axis=2) #img4_1
            seg1[count]  = np.expand_dims(seg4_0,axis=2)
            seg2[count]  = np.expand_dims(seg4_1,axis=2)
            y.append(0.0)
            count = count+1
            
            
#             folder_name1 = str(randrange(0,100)).zfill(3) 
            
#             if(folder_name1==folder_name):

#                 folder_name1 = str(int(folder_name) + 1).zfill(3) 
            
#             img5_0 = cv2.imread(path_corss_images + folder_name + '/'+ right+ '/'+ str(folder_name+'_'+right+'_'+str(pos_comb1[i][0]))+'.bmp')
#             img5_1 = cv2.imread(path_corss_images + folder_name1 + '/'+ right+ '/'+ str(folder_name1+'_'+right+'_'+str(pos_comb1[i][0]))+'.bmp')
#             img5_0 = translate_to_center(img5_0)
#             img5_1 = translate_to_center(img5_1)
            
#             img5_0 = cv2.resize(img4_0[:,:,0],(h,w))
#             img5_1 = cv2.resize(img4_1[:,:,0],(h,w))
#             name1 = folder_name + '/'+ str(pos_comb1[i][0]).zfill(2)
#             name2 = folder_name1 + '/'+ str(pos_comb1[i][1]).zfill(2)
#             seg5_0 = generate_mask()
#             seg5_1 = generate_mask()

#             seg5_0 = cv2.cvtColor(seg5_0,cv2.COLOR_BGR2GRAY)
#             seg5_1 = cv2.cvtColor(seg5_1,cv2.COLOR_BGR2GRAY)        

#             seg5_0 = cv2.resize(seg5_0,(h,w))
#             seg5_1 = cv2.resize(seg5_1,(h,w))
            
#             out1[count]  = np.expand_dims(img5_0,axis=2)#img4_0
#             out2[count]  = np.expand_dims(img5_1,axis=2) #img4_1
#             seg1[count]  = np.expand_dims(seg5_0,axis=2)
#             seg2[count]  = np.expand_dims(seg5_1,axis=2)
#             y.append(0.0)
#             count = count+1
            #print(i)
            
    ## this padding the data set for size 256x512 to maintain spect rationa nd segmentation parameters 
    train_out1 = out1
    train_out2 = out2 
    
    train_seg1 = seg1
    train_seg2 = seg2  
    
    
#     train_out1[:,0:240,0:320,:] = out1
#     train_out2[:,0:240,0:320,:] = out2 
    
#     train_seg1[:,0:240,0:320,:] = seg1
#     train_seg2[:,0:240,0:320,:] = seg2     
    
    return train_out1,train_out2,train_seg1,train_seg2,y
        #print(count)

# %%
#print(np.array(list(product([2,3,4,5], [8,9,10]))))
print(np.array(list(combinations([1, 2, 3], 2))))
# Out:
# [[1 2]
#  [1 3]
#  [2 3]]

# %%
#fileList = listOfFiles     
def imageLoader(path_input_images,folder_name_list,batch_size):

    L = len(folder_name_list)

    #this line is just to make the generator infinite, keras needs that    
    while True:

        batch_start = randrange(L-batch_size)
        batch_end = batch_start + batch_size

        if (batch_end < L):
            limit = min(batch_end, L)
            train_out1,train_out2,train_seg1,train_seg2,y_class = read_simaese_parametric_data(path_input_images,folder_name_list[batch_start:limit],batch_size)
            train_out1 = train_out1/255.
            train_out2 = train_out2/255.
            train_seg1 = train_seg1/255.
            train_seg2 = train_seg2/255.
            batch_start = batch_end
            batch_end = batch_start + batch_size
            #print(batch_start,batch_end)
            ## just for the test 
            #yield (train_out2,train_seg2)
            ## original
            yield ([train_out1,train_out2],[train_seg1,train_seg2,np.array(y_class)]) #a tuple with two numpy arrays with batch_size samples

# %%
folder_names = np.sort(os.listdir(path_input_images))
folder_name_list = folder_names[0:80] 
folder_name_list_test = folder_names[80:107]
print(len(folder_name_list_test))
# Out:
# 27

# %% [markdown]
# ### Function to check the GT and loader

# %%
def draw_haugh_circle(img_L,img_R, hough_param):        
    
    
    print('pair_classification =', int(hough_param[12]))
    cimg = img_L.copy()
    cv2.circle(cimg,(int(hough_param[0]),int(hough_param[1])),int(hough_param[2]),(0,255,0),2)
                # draw the center of the circle
    cv2.circle(cimg,(int(hough_param[0]),int(hough_param[1])),2,(0,255,0),3)

                #for i in circles_inner[0,:]:
                # draw the outer circle
    cv2.circle(cimg,(int(hough_param[3]),int(hough_param[4])),int(hough_param[5]),(0,0,255),2)
                # draw the center of the circle
    cv2.circle(cimg,(int(hough_param[3]),int(hough_param[4])),2,(0,0,255),3)
    plt.title('left_image')
    plt.imshow(cimg)
    plt.show()
    
    
    cimg = img_R.copy()
    cv2.circle(cimg,(int(hough_param[6]),int(hough_param[7])),int(hough_param[8]),(0,255,0),2)
                # draw the center of the circle
    cv2.circle(cimg,(int(hough_param[6]),int(hough_param[7])),2,(0,255,0),3)

                #for i in circles_inner[0,:]:
                # draw the outer circle
    cv2.circle(cimg,(int(hough_param[9]),int(hough_param[10])),int(hough_param[11]),(0,0,255),2)
                # draw the center of the circle
    cv2.circle(cimg,(int(hough_param[9]),int(hough_param[10])),2,(0,0,255),3)
    plt.title('right_image')
    plt.imshow(cimg)
    plt.show()

# %%
g=0
while (g < 10):

    Out = next(imageLoader(path_input_images,folder_name_list,4))
    g = g+1

# %%
images_L_R = Out[0]
image_L = images_L_R[0]
image_R = images_L_R[1]

mask_L_R_class = Out[1]

mask_L = mask_L_R_class[0]
mask_R = mask_L_R_class[1]
y = mask_L_R_class[2]
print(y[0])
print(image_L.shape)
# Out:
# 1.0
# (16, 128, 128, 1)

# %% [markdown]
# # mask_L.shape

# %%
plt.title('left_image')
plt.imshow(image_R[1],cmap='gray')
plt.show()

# %%
plt.title('left_mask')
plt.imshow(np.squeeze(mask_R[1]))
plt.show()

# %%
#pos_comb1 = np.array(list(combinations([1, 2, 3, 4, 5], 2)))
#pos_comb2 = np.array(list(combinations([6, 7, 8, 9, 10], 2)))

#neg_comb1 = np.array(list(product([2,3,4,5], [8,9,10])))
#print(neg_comb1)

# %%
folder_names = np.sort(os.listdir(path_input_images))

print(folder_names[0:20])
# Out:
# ['001' '002' '003' '004' '005' '006' '007' '008' '009' '010' '011' '012'
#  '013' '014' '015' '016' '017' '018' '019' '020']

# %%
# def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
#     """Function to add 2 convolutional layers with the parameters passed to it"""
#     # first layer
#     x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
#               kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
#     if batchnorm:
#         x = BatchNormalization()(x)
#     x = Activation('relu')(x)
    
#     # second layer
#     x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
#               kernel_initializer = 'he_normal', padding = 'same')(x)
#     if batchnorm:
#         x = BatchNormalization()(x)
#     x = Activation('relu')(x)
    
#     return x

# %%
initialize_weights = 'he_normal'
initialize_bias = 'he_normal'

# %%
def base_network_unet():
    input = Input(shape=(128,128,1), name="base_input")
    n_filters=16
    dropout=.1
    batchnorm=True
       
    c1 = Conv2D(n_filters*1, (3,3), activation='relu',
                   kernel_initializer=initialize_weights,padding = 'same', kernel_regularizer=l2(2e-4))(input)
    p1 = MaxPooling2D((2,2))(c1)           # (h/2,w/2,16)
    p1 = Dropout(dropout)(p1) 

    c2 = Conv2D(n_filters*2, (3,3), activation='relu',
                   kernel_initializer=initialize_weights,padding = 'same', kernel_regularizer=l2(2e-4))(p1)
    p2 = MaxPooling2D((2,2))(c2)  # (h/4,w/4,32)
    p2 = Dropout(dropout)(p2) 

    c3 = Conv2D(n_filters*4, (3,3), activation='relu',
                   kernel_initializer=initialize_weights, padding = 'same', kernel_regularizer=l2(2e-4))(p2)
    p3 = MaxPooling2D((2,2))(c3)  # (h/8,w/8,64)
    p3 = Dropout(dropout)(p3) 

    c4 = Conv2D(n_filters*8, (3,3), activation='relu',
                   kernel_initializer=initialize_weights, padding = 'same', kernel_regularizer=l2(2e-4))(p3)
    p4 = MaxPooling2D((2,2))(c4)  # (h/16,w/16,128)
    p4 = Dropout(dropout)(p4) 

    c5 = Conv2D(n_filters*16, (3,3), activation='relu',
                   kernel_initializer=initialize_weights, padding = 'same', kernel_regularizer=l2(2e-4))(p4)      # (h/16,w/16,256)


    print("encoder done")


    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)  # (h/8,w/8,128)
    u6 = concatenate([u6, c4])   # (h/8,w/8,128)
    u6 = Dropout(dropout)(u6)
        
    c6 = Conv2D(n_filters*8, (3,3), activation='relu',
                   kernel_initializer=initialize_weights, padding = 'same', kernel_regularizer=l2(2e-4))(u6) # (h/8,w/8,128)

    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)  # (h/4,w/4,64)
    u7 = concatenate([u7, c3])   # (h/8,w/8,128)
    u7 = Dropout(dropout)(u7)
    c7 = Conv2D(n_filters*4, (3,3), activation='relu',
                   kernel_initializer=initialize_weights, padding = 'same', kernel_regularizer=l2(2e-4))(u7) # (h/4,w/4,64)

    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)  # (h/2,w/2,32)
    u8 = concatenate([u8, c2])   # (h/2,w/2,32)
    u8 = Dropout(dropout)(u8)
    c8 = Conv2D(n_filters*2, (3,3), activation='relu',
                   kernel_initializer=initialize_weights, padding = 'same', kernel_regularizer=l2(2e-4))(u8)     # (h/2,w/2,32)

    u9 = Conv2DTranspose(n_filters, (3, 3), strides = (2, 2), padding = 'same')(c8)  # (h,w,16)
    u9 = concatenate([u9, c1])   # (h,w,16)
    u9 = Dropout(dropout)(u9)
    c9 = Conv2D(n_filters, (3,3), activation='relu',
                   kernel_initializer=initialize_weights, padding = 'same', kernel_regularizer=l2(2e-4))(u9)     # (h,w,16)    


    print("decoder done . . .  siamese network will start" )
    X_outputs = Conv2D(1,(1,1),activation='sigmoid',name='seg_out')(c9)
   
    print("simaese model done")
    return Model(inputs=input, outputs=[X_outputs,c9])

# %%
def base_network_siamese():
    
    input = Input(shape=(128,128,16), name="base_input")
#     degrees  = tf.constant(0,dtype='float32')
#     r1 = tfa.image.rotate(input[0],input[1])
    
    c10 = Conv2D(64, (10,10), activation='relu',
                   kernel_initializer=initialize_weights, kernel_regularizer=l2(2e-4))(input)
    p10 = MaxPooling2D()(c10)
    
#     r10 = tfa.image.rotate(p10,degrees, interpolation='BILINEAR')
    
    c11 = Conv2D(128, (7,7), activation='relu',
                     kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4))(p10)
    p11 = MaxPooling2D()(c11)
    c12 = Conv2D(128, (4,4), activation='relu', kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4))(p11)
    p12 = MaxPooling2D()(c12)
    c13 = Conv2D(256, (4,4), activation='relu', kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4))(p12)
    a1 = Flatten()(c13)
    a2 = Dense(128, activation='relu',
                   kernel_regularizer=l2(1e-3),
                   kernel_initializer=initialize_weights,bias_initializer=initialize_bias)(a1)  
    
    print("simaese model done")
    return Model(inputs=input, outputs=a2)

# %%
def euclidean_distance(vects):
    x, y = vects
    
    x0, x1, x2, x3, x4 = tf.split(x, num_or_size_splits=5, axis=1)
    
    y0, y1, y2, y3, y4 = tf.split(y, num_or_size_splits=5, axis=1)

#     v_size =128
#     sum_square_1 = K.sum(K.square(x[0:128] - y[0:128]), axis=1, keepdims=True)           ## batch_size x 1 
#     sum_square_2 = K.sum(K.square(x[0:128] - y[128:2*128]), axis=1, keepdims=True)    ## batch_size x 1 
#     sum_square_3 = K.sum(K.square(x[0:128] - y[2*128:3*128]), axis=1, keepdims=True)    ## batch_size x 1 
#     sum_square_4 = K.sum(K.square(x[0:128] - y[3*128:4*128]), axis=1, keepdims=True)    ## batch_size x 1 
#     sum_square_5 = K.sum(K.square(x[0:128] - y[4*128:5*128]), axis=1, keepdims=True)    ## batch_size x 1 
    
    
#     min_sum_square1 =  K.minimum(sum_square_1,sum_square_2)
#     min_sum_square2 = K.minimum(sum_square_3,sum_square_4)
#     min_sum_square3 = K.minimum(min_sum_square1,min_sum_square2)
#     min_sum_square4 = K.minimum(min_sum_square3,sum_square_5)
    
    
    
    sum_square_1 = K.sum(K.square(x0 - y0), axis=1, keepdims=True)           ## batch_size x 1 
    sum_square_2 = K.sum(K.square(x0 - y1), axis=1, keepdims=True)    ## batch_size x 1 
    sum_square_3 = K.sum(K.square(x0 - y2), axis=1, keepdims=True)    ## batch_size x 1 
    sum_square_4 = K.sum(K.square(x0 - y3), axis=1, keepdims=True)    ## batch_size x 1 
    sum_square_5 = K.sum(K.square(x0 - y4), axis=1, keepdims=True)    ## batch_size x 1 
    
    
    min_sum_square1 =  K.minimum(sum_square_1,sum_square_2)
    min_sum_square2 = K.minimum(sum_square_3,sum_square_4)
    min_sum_square3 = K.minimum(min_sum_square1,min_sum_square2)
    min_sum_square4 = K.minimum(min_sum_square3,sum_square_5) 
    
    
    
    return K.sqrt(K.maximum(min_sum_square4, K.epsilon()))


def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

# %%
base_network_1 = base_network_unet()
plot_model(base_network_1, show_shapes=True, show_layer_names=True, to_file='base-model.png')
# Out:
# encoder done
# decoder done . . .  siamese network will start
# simaese model done
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
base_network_2 = base_network_siamese()
plot_model(base_network_2, show_shapes=True, show_layer_names=True, to_file='base-model.png')
# Out:
# simaese model done
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
# create the left input and point to the base network
input_a = Input(shape=(128,128,1), name="left_input")

seg_a , seg_logit_a = base_network_1(input_a)

# create the right input and point to the base network
input_b = Input(shape=(128,128,1), name="right_input")

seg_b, seg_logit_b = base_network_1(input_b)

degree_1  = (2*np.pi/360)
delta = .000001


seg_logit_b_1 = RandomRotation(factor=(degree_1,degree_1+delta))(seg_logit_b)
seg_logit_b_2 = RandomRotation(factor=(2*degree_1,2*degree_1+delta))(seg_logit_b)
seg_logit_b_n1 = RandomRotation(factor=(-1*degree_1,-1*degree_1+delta))(seg_logit_b)
seg_logit_b_n2 = RandomRotation(factor=(-2*degree_1,-2*degree_1+delta))(seg_logit_b)


vect_a0 = base_network_2(seg_logit_a)





vect_0 = base_network_2(seg_logit_b)
vect_1 = base_network_2(seg_logit_b_1)
vect_2 = base_network_2(seg_logit_b_2)
vect_n1 = base_network_2(seg_logit_b_n1)
vect_n2 = base_network_2(seg_logit_b_n2)

vect_output_b = concatenate([vect_0, vect_1, vect_2, vect_n1, vect_n2]) 

vect_output_a = concatenate([vect_a0, vect_1, vect_2, vect_n1, vect_n2])  

# # measure the similarity of the two vector outputs
output_siasmese = Lambda(euclidean_distance, name="output_layer", output_shape=(128,1))([vect_output_a, vect_output_b])

# # specify the inputs and output of the model
model = Model([input_a, input_b], [seg_a,seg_b,output_siasmese])

# %%
plot_model(model, show_shapes=True, show_layer_names=True, to_file='outer-model.png')
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
def contrastive_loss_with_margin(margin):
    def contrastive_loss(y_true, y_pred):
        '''Contrastive loss from Hadsell-et-al.'06
        http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
        '''
        square_pred = K.square(y_pred)
        margin_square = K.square(K.maximum(margin - y_pred, 0))
        return K.mean(y_true * square_pred + (1 - y_true) * margin_square)
    return contrastive_loss

# %%
#optimizer = keras.optimizers.Adam(lr = 0.0001)


#siamese_model.compile(loss=custom_loss, optimizer=optimizer, metrics = ['mae', 'acc'])
model.compile(loss = {'model' : "binary_crossentropy",
                      'model_1' : "binary_crossentropy",
                      'output_layer' : contrastive_loss_with_margin(margin=1)
                     },optimizer='Adam', metrics = ['mae', 'acc'])

# %%
#steps_per_epoch = train_length // batch_size
batch_size = 4
steps_per_epoch = len(folder_name_list) // batch_size
validation_steps = len(folder_name_list_test) // batch_size

# %%
# history = siamese_model.fit_generator(imageLoader(path_input_images,folder_name_list,batch_size),steps_per_epoch,
#                     validation_data = imageLoader(path_input_images,folder_name_list_test,batch_size), 
#                     validation_steps=validation_steps, epochs=50)

# %%
history = model.fit_generator(imageLoader(path_input_images,folder_name_list,batch_size),steps_per_epoch,
                    validation_data = imageLoader(path_input_images,folder_name_list_test,batch_size), 
                    validation_steps=validation_steps, epochs=100)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 20/20 [==============================] - 246s 12s/step - loss: 3.5068 - model_loss: 0.6943 - model_1_loss: 0.6958 - output_layer_loss: 1.3958 - model_mae: 0.4834 - model_acc: 0.5439 - model_1_mae: 0.4838 - model_1_acc: 0.5426 - output_layer_mae: 1.1415 - output_layer_acc: 0.3811 - val_loss: 2.1912 - val_model_loss: 0.6542 - val_model_1_loss: 0.6506 - val_output_layer_loss: 0.2391 - val_model_mae: 0.4558 - val_model_acc: 0.6363 - val_model_1_mae: 0.4532 - val_model_1_acc: 0.6354 - val_output_layer_mae: 0.5981 - val_output_layer_acc: 0.3438
# Epoch 2/100
# 20/20 [==============================] - 223s 11s/step - loss: 2.1748 - model_loss: 0.6542 - model_1_loss: 0.6543 - output_layer_loss: 0.2244 - model_mae: 0.4533 - model_acc: 0.6345 - model_1_mae: 0.4532 - model_1_acc: 0.6330 - output_layer_mae: 0.6603 - output_layer_acc: 0.3448 - val_loss: 2.1593 - val_model_loss: 0.6451 - val_model_1_loss: 0.6465 - val_output_layer_loss: 0.2423 - val_model_mae: 0.4551 - val_model_acc: 0.6449 - val_model_1_mae: 0.4555 - val_model_1_acc: 0.6432 - val_output_layer_mae: 0.6013 - val_output_layer_acc: 0.3750
# Epoch 3/100
# 20/20 [==============================] - 224s 11s/step - loss: 2.1827 - model_loss: 0.6529 - model_1_loss: 0.6484 - output_layer_loss: 0.2617 - model_mae: 0.4567 - model_acc: 0.6398 - model_1_mae: 0.4542 - model_1_acc: 0.6396 - output_layer_mae: 0.6170 - output_layer_acc: 0.3316 - val_loss: 2.2008 - val_model_loss: 0.6414 - val_model_1_loss: 0.6423 - val_output_layer_loss: 0.3137 - val_model_mae: 0.4555 - val_model_acc: 0.6458 - val_model_1_mae: 0.4558 - val_model_1_acc: 0.6462 - val_output_layer_mae: 0.5573 - val_output_layer_acc: 0.4688
# Epoch 4/100
# 20/20 [==============================] - 225s 11s/step - loss: 2.1028 - model_loss: 0.6413 - model_1_loss: 0.6401 - output_layer_loss: 0.2229 - model_mae: 0.4510 - model_acc: 0.6455 - model_1_mae: 0.4507 - model_1_acc: 0.6477 - output_layer_mae: 0.6094 - output_layer_acc: 0.3632 - val_loss: 2.0526 - val_model_loss: 0.6330 - val_model_1_loss: 0.6368 - val_output_layer_loss: 0.1986 - val_model_mae: 0.4480 - val_model_acc: 0.6466 - val_model_1_mae: 0.4497 - val_model_1_acc: 0.6415 - val_output_layer_mae: 0.6457 - val_output_layer_acc: 0.3229
# Epoch 5/100
# 20/20 [==============================] - 224s 11s/step - loss: 2.0354 - model_loss: 0.6339 - model_1_loss: 0.6326 - output_layer_loss: 0.1891 - model_mae: 0.4436 - model_acc: 0.6425 - model_1_mae: 0.4430 - model_1_acc: 0.6419 - output_layer_mae: 0.6807 - output_layer_acc: 0.3379 - val_loss: 2.0139 - val_model_loss: 0.6163 - val_model_1_loss: 0.6140 - val_output_layer_loss: 0.2166 - val_model_mae: 0.4392 - val_model_acc: 0.6396 - val_model_1_mae: 0.4385 - val_model_1_acc: 0.6478 - val_output_layer_mae: 0.6263 - val_output_layer_acc: 0.3646
# Epoch 6/100
# 20/20 [==============================] - 223s 11s/step - loss: 1.9964 - model_loss: 0.6124 - model_1_loss: 0.6120 - output_layer_loss: 0.2089 - model_mae: 0.4306 - model_acc: 0.6451 - model_1_mae: 0.4301 - model_1_acc: 0.6456 - output_layer_mae: 0.6697 - output_layer_acc: 0.2943 - val_loss: 2.0351 - val_model_loss: 0.6031 - val_model_1_loss: 0.6020 - val_output_layer_loss: 0.2780 - val_model_mae: 0.4271 - val_model_acc: 0.6430 - val_model_1_mae: 0.4265 - val_model_1_acc: 0.6456 - val_output_layer_mae: 0.5827 - val_output_layer_acc: 0.3542
# Epoch 7/100
# 20/20 [==============================] - 223s 11s/step - loss: 1.9428 - model_loss: 0.5952 - model_1_loss: 0.5961 - output_layer_loss: 0.2032 - model_mae: 0.4145 - model_acc: 0.6460 - model_1_mae: 0.4148 - model_1_acc: 0.6458 - output_layer_mae: 0.7000 - output_layer_acc: 0.2852 - val_loss: 1.9052 - val_model_loss: 0.5831 - val_model_1_loss: 0.5837 - val_output_layer_loss: 0.2011 - val_model_mae: 0.4097 - val_model_acc: 0.6422 - val_model_1_mae: 0.4103 - val_model_1_acc: 0.6409 - val_output_layer_mae: 0.7104 - val_output_layer_acc: 0.2917
# Epoch 8/100
# 20/20 [==============================] - 223s 11s/step - loss: 1.9107 - model_loss: 0.5807 - model_1_loss: 0.5841 - output_layer_loss: 0.2118 - model_mae: 0.4047 - model_acc: 0.6447 - model_1_mae: 0.4074 - model_1_acc: 0.6435 - output_layer_mae: 0.7190 - output_layer_acc: 0.2835 - val_loss: 1.9434 - val_model_loss: 0.5756 - val_model_1_loss: 0.5708 - val_output_layer_loss: 0.2723 - val_model_mae: 0.4062 - val_model_acc: 0.6419 - val_model_1_mae: 0.4031 - val_model_1_acc: 0.6432 - val_output_layer_mae: 0.5845 - val_output_layer_acc: 0.4167
# Epoch 9/100
# 20/20 [==============================] - 223s 11s/step - loss: 1.9003 - model_loss: 0.5656 - model_1_loss: 0.5627 - output_layer_loss: 0.2498 - model_mae: 0.3857 - model_acc: 0.6424 - model_1_mae: 0.3847 - model_1_acc: 0.6460 - output_layer_mae: 0.6151 - output_layer_acc: 0.3694 - val_loss: 1.7210 - val_model_loss: 0.5063 - val_model_1_loss: 0.5034 - val_output_layer_loss: 0.1957 - val_model_mae: 0.3644 - val_model_acc: 0.6620 - val_model_1_mae: 0.3637 - val_model_1_acc: 0.6682 - val_output_layer_mae: 0.6335 - val_output_layer_acc: 0.3021
# Epoch 10/100
# 20/20 [==============================] - 223s 11s/step - loss: 1.6974 - model_loss: 0.4842 - model_1_loss: 0.4816 - output_layer_loss: 0.2180 - model_mae: 0.3446 - model_acc: 0.6812 - model_1_mae: 0.3430 - model_1_acc: 0.6827 - output_layer_mae: 0.6560 - output_layer_acc: 0.3169 - val_loss: 1.6047 - val_model_loss: 0.4220 - val_model_1_loss: 0.4213 - val_output_layer_loss: 0.2538 - val_model_mae: 0.3074 - val_model_acc: 0.8019 - val_model_1_mae: 0.3073 - val_model_1_acc: 0.8036 - val_output_layer_mae: 0.5949 - val_output_layer_acc: 0.3750
# Epoch 11/100
# 20/20 [==============================] - 223s 11s/step - loss: 1.7143 - model_loss: 0.4688 - model_1_loss: 0.4740 - output_layer_loss: 0.2656 - model_mae: 0.3172 - model_acc: 0.7207 - model_1_mae: 0.3188 - model_1_acc: 0.7182 - output_layer_mae: 0.6495 - output_layer_acc: 0.4182 - val_loss: 1.5547 - val_model_loss: 0.3978 - val_model_1_loss: 0.3893 - val_output_layer_loss: 0.2658 - val_model_mae: 0.2706 - val_model_acc: 0.8198 - val_model_1_mae: 0.2693 - val_model_1_acc: 0.8226 - val_output_layer_mae: 0.6114 - val_output_layer_acc: 0.3750
# Epoch 12/100
# 20/20 [==============================] - 224s 11s/step - loss: 1.7245 - model_loss: 0.4505 - model_1_loss: 0.4487 - output_layer_loss: 0.3248 - model_mae: 0.3126 - model_acc: 0.7466 - model_1_mae: 0.3121 - model_1_acc: 0.7510 - output_layer_mae: 0.6085 - output_layer_acc: 0.4202 - val_loss: 1.7743 - val_model_loss: 0.4501 - val_model_1_loss: 0.4571 - val_output_layer_loss: 0.3697 - val_model_mae: 0.2737 - val_model_acc: 0.6517 - val_model_1_mae: 0.2760 - val_model_1_acc: 0.6503 - val_output_layer_mae: 0.5373 - val_output_layer_acc: 0.5000
# Epoch 13/100
# 20/20 [==============================] - 223s 11s/step - loss: 1.6240 - model_loss: 0.4005 - model_1_loss: 0.3960 - output_layer_loss: 0.3311 - model_mae: 0.2668 - model_acc: 0.7340 - model_1_mae: 0.2653 - model_1_acc: 0.7354 - output_layer_mae: 0.5626 - output_layer_acc: 0.4384 - val_loss: 1.3955 - val_model_loss: 0.3553 - val_model_1_loss: 0.3566 - val_output_layer_loss: 0.1893 - val_model_mae: 0.2452 - val_model_acc: 0.8715 - val_model_1_mae: 0.2451 - val_model_1_acc: 0.8714 - val_output_layer_mae: 0.6975 - val_output_layer_acc: 0.3021
# Epoch 14/100
# 20/20 [==============================] - 222s 11s/step - loss: 1.4250 - model_loss: 0.3465 - model_1_loss: 0.3479 - output_layer_loss: 0.2369 - model_mae: 0.2470 - model_acc: 0.8653 - model_1_mae: 0.2477 - model_1_acc: 0.8635 - output_layer_mae: 0.6228 - output_layer_acc: 0.3551 - val_loss: 1.8354 - val_model_loss: 0.4624 - val_model_1_loss: 0.4555 - val_output_layer_loss: 0.4269 - val_model_mae: 0.2528 - val_model_acc: 0.7599 - val_model_1_mae: 0.2507 - val_model_1_acc: 0.7645 - val_output_layer_mae: 0.8394 - val_output_layer_acc: 0.3125
# Epoch 15/100
# 20/20 [==============================] - 223s 11s/step - loss: 1.4907 - model_loss: 0.3505 - model_1_loss: 0.3537 - output_layer_loss: 0.2967 - model_mae: 0.2513 - model_acc: 0.8382 - model_1_mae: 0.2528 - model_1_acc: 0.8368 - output_layer_mae: 0.6430 - output_layer_acc: 0.3862 - val_loss: 1.6266 - val_model_loss: 0.3347 - val_model_1_loss: 0.3326 - val_output_layer_loss: 0.4730 - val_model_mae: 0.2404 - val_model_acc: 0.8277 - val_model_1_mae: 0.2389 - val_model_1_acc: 0.8296 - val_output_layer_mae: 0.6216 - val_output_layer_acc: 0.4062
# Epoch 16/100
# 20/20 [==============================] - 223s 11s/step - loss: 1.4010 - model_loss: 0.3258 - model_1_loss: 0.3264 - output_layer_loss: 0.2633 - model_mae: 0.2249 - model_acc: 0.8339 - model_1_mae: 0.2255 - model_1_acc: 0.8318 - output_layer_mae: 0.5983 - output_layer_acc: 0.3695 - val_loss: 1.3061 - val_model_loss: 0.3105 - val_model_1_loss: 0.3086 - val_output_layer_loss: 0.2038 - val_model_mae: 0.1997 - val_model_acc: 0.8483 - val_model_1_mae: 0.1990 - val_model_1_acc: 0.8504 - val_output_layer_mae: 0.6424 - val_output_layer_acc: 0.2812
# Epoch 17/100
# 20/20 [==============================] - 223s 11s/step - loss: 1.3044 - model_loss: 0.2679 - model_1_loss: 0.2711 - output_layer_loss: 0.2836 - model_mae: 0.1805 - model_acc: 0.8669 - model_1_mae: 0.1814 - model_1_acc: 0.8655 - output_layer_mae: 0.5942 - output_layer_acc: 0.4377 - val_loss: 1.2664 - val_model_loss: 0.2533 - val_model_1_loss: 0.2599 - val_output_layer_loss: 0.2758 - val_model_mae: 0.1752 - val_model_acc: 0.8644 - val_model_1_mae: 0.1778 - val_model_1_acc: 0.8595 - val_output_layer_mae: 0.7668 - val_output_layer_acc: 0.3438
# Epoch 18/100
# 20/20 [==============================] - 223s 11s/step - loss: 1.2282 - model_loss: 0.2304 - model_1_loss: 0.2330 - output_layer_loss: 0.2891 - model_mae: 0.1555 - model_acc: 0.8778 - model_1_mae: 0.1557 - model_1_acc: 0.8779 - output_layer_mae: 0.6292 - output_layer_acc: 0.3988 - val_loss: 1.3240 - val_model_loss: 0.2565 - val_model_1_loss: 0.2581 - val_output_layer_loss: 0.3387 - val_model_mae: 0.1585 - val_model_acc: 0.8616 - val_model_1_mae: 0.1585 - val_model_1_acc: 0.8581 - val_output_layer_mae: 0.6821 - val_output_layer_acc: 0.4271
# Epoch 19/100
# 20/20 [==============================] - 222s 11s/step - loss: 1.1852 - model_loss: 0.2165 - model_1_loss: 0.2156 - output_layer_loss: 0.2842 - model_mae: 0.1380 - model_acc: 0.8852 - model_1_mae: 0.1382 - model_1_acc: 0.8857 - output_layer_mae: 0.6748 - output_layer_acc: 0.3729 - val_loss: 1.1136 - val_model_loss: 0.2025 - val_model_1_loss: 0.1981 - val_output_layer_loss: 0.2496 - val_model_mae: 0.1389 - val_model_acc: 0.8952 - val_model_1_mae: 0.1372 - val_model_1_acc: 0.8947 - val_output_layer_mae: 0.6055 - val_output_layer_acc: 0.3854
# Epoch 20/100
# 20/20 [==============================] - 222s 11s/step - loss: 1.0986 - model_loss: 0.2026 - model_1_loss: 0.2070 - output_layer_loss: 0.2274 - model_mae: 0.1373 - model_acc: 0.9048 - model_1_mae: 0.1388 - model_1_acc: 0.9029 - output_layer_mae: 0.6453 - output_layer_acc: 0.3342 - val_loss: 1.1671 - val_model_loss: 0.2256 - val_model_1_loss: 0.2203 - val_output_layer_loss: 0.2654 - val_model_mae: 0.1374 - val_model_acc: 0.8827 - val_model_1_mae: 0.1352 - val_model_1_acc: 0.8834 - val_output_layer_mae: 0.7428 - val_output_layer_acc: 0.2917
# Epoch 21/100
# 20/20 [==============================] - 223s 11s/step - loss: 1.2659 - model_loss: 0.2115 - model_1_loss: 0.2055 - output_layer_loss: 0.3954 - model_mae: 0.1356 - model_acc: 0.8918 - model_1_mae: 0.1331 - model_1_acc: 0.8952 - output_layer_mae: 0.6392 - output_layer_acc: 0.4146 - val_loss: 1.3415 - val_model_loss: 0.1962 - val_model_1_loss: 0.1978 - val_output_layer_loss: 0.4997 - val_model_mae: 0.1292 - val_model_acc: 0.8978 - val_model_1_mae: 0.1281 - val_model_1_acc: 0.8937 - val_output_layer_mae: 0.5000 - val_output_layer_acc: 0.5000
# Epoch 22/100
# 20/20 [==============================] - 222s 11s/step - loss: 1.2781 - model_loss: 0.1959 - model_1_loss: 0.1945 - output_layer_loss: 0.4420 - model_mae: 0.1161 - model_acc: 0.9042 - model_1_mae: 0.1161 - model_1_acc: 0.9047 - output_layer_mae: 0.5080 - output_layer_acc: 0.4944 - val_loss: 2.1820 - val_model_loss: 0.2187 - val_model_1_loss: 0.2140 - val_output_layer_loss: 1.3085 - val_model_mae: 0.1462 - val_model_acc: 0.9129 - val_model_1_mae: 0.1432 - val_model_1_acc: 0.9150 - val_output_layer_mae: 1.4553 - val_output_layer_acc: 0.4583
# Epoch 23/100
# 20/20 [==============================] - 223s 11s/step - loss: 1.3871 - model_loss: 0.2892 - model_1_loss: 0.2928 - output_layer_loss: 0.3650 - model_mae: 0.1618 - model_acc: 0.8890 - model_1_mae: 0.1635 - model_1_acc: 0.8877 - output_layer_mae: 0.6858 - output_layer_acc: 0.3860 - val_loss: 1.1938 - val_model_loss: 0.2494 - val_model_1_loss: 0.2394 - val_output_layer_loss: 0.2669 - val_model_mae: 0.1774 - val_model_acc: 0.9021 - val_model_1_mae: 0.1725 - val_model_1_acc: 0.9098 - val_output_layer_mae: 0.6065 - val_output_layer_acc: 0.3542
# Epoch 24/100
# 20/20 [==============================] - 222s 11s/step - loss: 1.1017 - model_loss: 0.2102 - model_1_loss: 0.2084 - output_layer_loss: 0.2463 - model_mae: 0.1432 - model_acc: 0.9225 - model_1_mae: 0.1425 - model_1_acc: 0.9227 - output_layer_mae: 0.6611 - output_layer_acc: 0.3396 - val_loss: 0.9931 - val_model_loss: 0.1870 - val_model_1_loss: 0.1843 - val_output_layer_loss: 0.1900 - val_model_mae: 0.1251 - val_model_acc: 0.9255 - val_model_1_mae: 0.1238 - val_model_1_acc: 0.9258 - val_output_layer_mae: 0.6659 - val_output_layer_acc: 0.2812
# Epoch 25/100
# 20/20 [==============================] - 222s 11s/step - loss: 1.0890 - model_loss: 0.1832 - model_1_loss: 0.1824 - output_layer_loss: 0.2932 - model_mae: 0.1176 - model_acc: 0.9290 - model_1_mae: 0.1174 - model_1_acc: 0.9289 - output_layer_mae: 0.5997 - output_layer_acc: 0.3753 - val_loss: 0.9990 - val_model_loss: 0.1717 - val_model_1_loss: 0.1779 - val_output_layer_loss: 0.2240 - val_model_mae: 0.1183 - val_model_acc: 0.9322 - val_model_1_mae: 0.1203 - val_model_1_acc: 0.9294 - val_output_layer_mae: 0.6573 - val_output_layer_acc: 0.3333
# Epoch 26/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.9980 - model_loss: 0.1811 - model_1_loss: 0.1802 - output_layer_loss: 0.2128 - model_mae: 0.1117 - model_acc: 0.9282 - model_1_mae: 0.1115 - model_1_acc: 0.9289 - output_layer_mae: 0.6369 - output_layer_acc: 0.3149 - val_loss: 0.9846 - val_model_loss: 0.1744 - val_model_1_loss: 0.1794 - val_output_layer_loss: 0.2115 - val_model_mae: 0.1174 - val_model_acc: 0.9297 - val_model_1_mae: 0.1180 - val_model_1_acc: 0.9282 - val_output_layer_mae: 0.7124 - val_output_layer_acc: 0.2812
# Epoch 27/100
# 20/20 [==============================] - 223s 11s/step - loss: 1.0020 - model_loss: 0.1704 - model_1_loss: 0.1739 - output_layer_loss: 0.2401 - model_mae: 0.1037 - model_acc: 0.9308 - model_1_mae: 0.1045 - model_1_acc: 0.9305 - output_layer_mae: 0.6269 - output_layer_acc: 0.3241 - val_loss: 0.9473 - val_model_loss: 0.1627 - val_model_1_loss: 0.1630 - val_output_layer_loss: 0.2088 - val_model_mae: 0.1089 - val_model_acc: 0.9332 - val_model_1_mae: 0.1077 - val_model_1_acc: 0.9358 - val_output_layer_mae: 0.6544 - val_output_layer_acc: 0.2917
# Epoch 28/100
# 20/20 [==============================] - 222s 11s/step - loss: 0.9400 - model_loss: 0.1605 - model_1_loss: 0.1597 - output_layer_loss: 0.2086 - model_mae: 0.0970 - model_acc: 0.9355 - model_1_mae: 0.0965 - model_1_acc: 0.9363 - output_layer_mae: 0.6155 - output_layer_acc: 0.3160 - val_loss: 0.9863 - val_model_loss: 0.1913 - val_model_1_loss: 0.1953 - val_output_layer_loss: 0.1931 - val_model_mae: 0.1249 - val_model_acc: 0.9226 - val_model_1_mae: 0.1267 - val_model_1_acc: 0.9192 - val_output_layer_mae: 0.6972 - val_output_layer_acc: 0.2500
# Epoch 29/100
# 20/20 [==============================] - 222s 11s/step - loss: 0.9993 - model_loss: 0.1754 - model_1_loss: 0.1643 - output_layer_loss: 0.2546 - model_mae: 0.1019 - model_acc: 0.9296 - model_1_mae: 0.0979 - model_1_acc: 0.9334 - output_layer_mae: 0.6187 - output_layer_acc: 0.3545 - val_loss: 1.0106 - val_model_loss: 0.1951 - val_model_1_loss: 0.1960 - val_output_layer_loss: 0.2190 - val_model_mae: 0.1231 - val_model_acc: 0.9192 - val_model_1_mae: 0.1236 - val_model_1_acc: 0.9189 - val_output_layer_mae: 0.6323 - val_output_layer_acc: 0.3229
# Epoch 30/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.9198 - model_loss: 0.1590 - model_1_loss: 0.1610 - output_layer_loss: 0.2007 - model_mae: 0.0939 - model_acc: 0.9358 - model_1_mae: 0.0945 - model_1_acc: 0.9346 - output_layer_mae: 0.6399 - output_layer_acc: 0.2902 - val_loss: 0.9241 - val_model_loss: 0.1762 - val_model_1_loss: 0.1625 - val_output_layer_loss: 0.1909 - val_model_mae: 0.1110 - val_model_acc: 0.9253 - val_model_1_mae: 0.1069 - val_model_1_acc: 0.9321 - val_output_layer_mae: 0.6714 - val_output_layer_acc: 0.2604
# Epoch 31/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.9197 - model_loss: 0.1583 - model_1_loss: 0.1613 - output_layer_loss: 0.2070 - model_mae: 0.0957 - model_acc: 0.9343 - model_1_mae: 0.0961 - model_1_acc: 0.9346 - output_layer_mae: 0.6415 - output_layer_acc: 0.3389 - val_loss: 0.9479 - val_model_loss: 0.1625 - val_model_1_loss: 0.1675 - val_output_layer_loss: 0.2290 - val_model_mae: 0.1073 - val_model_acc: 0.9332 - val_model_1_mae: 0.1089 - val_model_1_acc: 0.9308 - val_output_layer_mae: 0.6182 - val_output_layer_acc: 0.3438
# Epoch 32/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.9054 - model_loss: 0.1593 - model_1_loss: 0.1534 - output_layer_loss: 0.2053 - model_mae: 0.0923 - model_acc: 0.9344 - model_1_mae: 0.0908 - model_1_acc: 0.9365 - output_layer_mae: 0.6420 - output_layer_acc: 0.3285 - val_loss: 0.9520 - val_model_loss: 0.1697 - val_model_1_loss: 0.1733 - val_output_layer_loss: 0.2262 - val_model_mae: 0.1083 - val_model_acc: 0.9277 - val_model_1_mae: 0.1093 - val_model_1_acc: 0.9271 - val_output_layer_mae: 0.6073 - val_output_layer_acc: 0.3333
# Epoch 33/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.8865 - model_loss: 0.1475 - model_1_loss: 0.1506 - output_layer_loss: 0.2071 - model_mae: 0.0855 - model_acc: 0.9393 - model_1_mae: 0.0866 - model_1_acc: 0.9372 - output_layer_mae: 0.6241 - output_layer_acc: 0.3037 - val_loss: 1.0413 - val_model_loss: 0.2313 - val_model_1_loss: 0.2112 - val_output_layer_loss: 0.2225 - val_model_mae: 0.1379 - val_model_acc: 0.8987 - val_model_1_mae: 0.1309 - val_model_1_acc: 0.9081 - val_output_layer_mae: 0.6028 - val_output_layer_acc: 0.3333
# Epoch 34/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.9038 - model_loss: 0.1561 - model_1_loss: 0.1614 - output_layer_loss: 0.2114 - model_mae: 0.0933 - model_acc: 0.9356 - model_1_mae: 0.0948 - model_1_acc: 0.9337 - output_layer_mae: 0.6337 - output_layer_acc: 0.3114 - val_loss: 0.8784 - val_model_loss: 0.1508 - val_model_1_loss: 0.1576 - val_output_layer_loss: 0.1995 - val_model_mae: 0.0980 - val_model_acc: 0.9352 - val_model_1_mae: 0.0996 - val_model_1_acc: 0.9333 - val_output_layer_mae: 0.7176 - val_output_layer_acc: 0.3125
# Epoch 35/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.9091 - model_loss: 0.1506 - model_1_loss: 0.1529 - output_layer_loss: 0.2367 - model_mae: 0.0884 - model_acc: 0.9383 - model_1_mae: 0.0894 - model_1_acc: 0.9369 - output_layer_mae: 0.6485 - output_layer_acc: 0.3201 - val_loss: 0.9143 - val_model_loss: 0.1785 - val_model_1_loss: 0.1623 - val_output_layer_loss: 0.2085 - val_model_mae: 0.1081 - val_model_acc: 0.9275 - val_model_1_mae: 0.1016 - val_model_1_acc: 0.9353 - val_output_layer_mae: 0.6856 - val_output_layer_acc: 0.3021
# Epoch 36/100
# 20/20 [==============================] - 224s 11s/step - loss: 0.8370 - model_loss: 0.1430 - model_1_loss: 0.1435 - output_layer_loss: 0.1867 - model_mae: 0.0822 - model_acc: 0.9396 - model_1_mae: 0.0818 - model_1_acc: 0.9397 - output_layer_mae: 0.6880 - output_layer_acc: 0.2658 - val_loss: 0.9002 - val_model_loss: 0.1536 - val_model_1_loss: 0.1544 - val_output_layer_loss: 0.2326 - val_model_mae: 0.0961 - val_model_acc: 0.9330 - val_model_1_mae: 0.0958 - val_model_1_acc: 0.9329 - val_output_layer_mae: 0.5830 - val_output_layer_acc: 0.3229
# Epoch 37/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.8540 - model_loss: 0.1509 - model_1_loss: 0.1460 - output_layer_loss: 0.1987 - model_mae: 0.0849 - model_acc: 0.9367 - model_1_mae: 0.0828 - model_1_acc: 0.9391 - output_layer_mae: 0.6361 - output_layer_acc: 0.3109 - val_loss: 0.8443 - val_model_loss: 0.1592 - val_model_1_loss: 0.1431 - val_output_layer_loss: 0.1873 - val_model_mae: 0.0980 - val_model_acc: 0.9305 - val_model_1_mae: 0.0905 - val_model_1_acc: 0.9407 - val_output_layer_mae: 0.6938 - val_output_layer_acc: 0.2292
# Epoch 38/100
# 20/20 [==============================] - 222s 11s/step - loss: 0.8618 - model_loss: 0.1451 - model_1_loss: 0.1508 - output_layer_loss: 0.2126 - model_mae: 0.0835 - model_acc: 0.9377 - model_1_mae: 0.0851 - model_1_acc: 0.9353 - output_layer_mae: 0.6472 - output_layer_acc: 0.3064 - val_loss: 0.8143 - val_model_loss: 0.1419 - val_model_1_loss: 0.1386 - val_output_layer_loss: 0.1846 - val_model_mae: 0.0896 - val_model_acc: 0.9367 - val_model_1_mae: 0.0871 - val_model_1_acc: 0.9403 - val_output_layer_mae: 0.7230 - val_output_layer_acc: 0.3021
# Epoch 39/100
# 20/20 [==============================] - 224s 11s/step - loss: 0.8429 - model_loss: 0.1457 - model_1_loss: 0.1401 - output_layer_loss: 0.2093 - model_mae: 0.0833 - model_acc: 0.9378 - model_1_mae: 0.0808 - model_1_acc: 0.9402 - output_layer_mae: 0.6237 - output_layer_acc: 0.3029 - val_loss: 0.8798 - val_model_loss: 0.1751 - val_model_1_loss: 0.1679 - val_output_layer_loss: 0.1926 - val_model_mae: 0.1097 - val_model_acc: 0.9268 - val_model_1_mae: 0.1070 - val_model_1_acc: 0.9299 - val_output_layer_mae: 0.6772 - val_output_layer_acc: 0.3229
# Epoch 40/100
# 20/20 [==============================] - 224s 11s/step - loss: 0.8359 - model_loss: 0.1364 - model_1_loss: 0.1427 - output_layer_loss: 0.2140 - model_mae: 0.0787 - model_acc: 0.9407 - model_1_mae: 0.0809 - model_1_acc: 0.9380 - output_layer_mae: 0.6344 - output_layer_acc: 0.3256 - val_loss: 0.7844 - val_model_loss: 0.1334 - val_model_1_loss: 0.1409 - val_output_layer_loss: 0.1709 - val_model_mae: 0.0884 - val_model_acc: 0.9438 - val_model_1_mae: 0.0909 - val_model_1_acc: 0.9396 - val_output_layer_mae: 0.6992 - val_output_layer_acc: 0.2396
# Epoch 41/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.8187 - model_loss: 0.1296 - model_1_loss: 0.1443 - output_layer_loss: 0.2069 - model_mae: 0.0743 - model_acc: 0.9433 - model_1_mae: 0.0793 - model_1_acc: 0.9373 - output_layer_mae: 0.6247 - output_layer_acc: 0.3126 - val_loss: 0.8423 - val_model_loss: 0.1518 - val_model_1_loss: 0.1584 - val_output_layer_loss: 0.1977 - val_model_mae: 0.0985 - val_model_acc: 0.9391 - val_model_1_mae: 0.1014 - val_model_1_acc: 0.9358 - val_output_layer_mae: 0.6535 - val_output_layer_acc: 0.3438
# Epoch 42/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.7992 - model_loss: 0.1365 - model_1_loss: 0.1341 - output_layer_loss: 0.1955 - model_mae: 0.0778 - model_acc: 0.9404 - model_1_mae: 0.0770 - model_1_acc: 0.9417 - output_layer_mae: 0.6363 - output_layer_acc: 0.2838 - val_loss: 0.8347 - val_model_loss: 0.1545 - val_model_1_loss: 0.1640 - val_output_layer_loss: 0.1870 - val_model_mae: 0.0918 - val_model_acc: 0.9348 - val_model_1_mae: 0.0944 - val_model_1_acc: 0.9303 - val_output_layer_mae: 0.6882 - val_output_layer_acc: 0.2604
# Epoch 43/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.8255 - model_loss: 0.1372 - model_1_loss: 0.1476 - output_layer_loss: 0.2128 - model_mae: 0.0780 - model_acc: 0.9404 - model_1_mae: 0.0814 - model_1_acc: 0.9362 - output_layer_mae: 0.6331 - output_layer_acc: 0.3487 - val_loss: 0.8288 - val_model_loss: 0.1532 - val_model_1_loss: 0.1481 - val_output_layer_loss: 0.2040 - val_model_mae: 0.0966 - val_model_acc: 0.9379 - val_model_1_mae: 0.0944 - val_model_1_acc: 0.9390 - val_output_layer_mae: 0.6619 - val_output_layer_acc: 0.3438
# Epoch 44/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.8105 - model_loss: 0.1330 - model_1_loss: 0.1461 - output_layer_loss: 0.2092 - model_mae: 0.0779 - model_acc: 0.9413 - model_1_mae: 0.0822 - model_1_acc: 0.9360 - output_layer_mae: 0.6306 - output_layer_acc: 0.3198 - val_loss: 0.8009 - val_model_loss: 0.1557 - val_model_1_loss: 0.1509 - val_output_layer_loss: 0.1760 - val_model_mae: 0.0989 - val_model_acc: 0.9382 - val_model_1_mae: 0.0974 - val_model_1_acc: 0.9411 - val_output_layer_mae: 0.6970 - val_output_layer_acc: 0.2396
# Epoch 45/100
# 20/20 [==============================] - 222s 11s/step - loss: 0.7734 - model_loss: 0.1349 - model_1_loss: 0.1317 - output_layer_loss: 0.1900 - model_mae: 0.0763 - model_acc: 0.9402 - model_1_mae: 0.0751 - model_1_acc: 0.9415 - output_layer_mae: 0.6376 - output_layer_acc: 0.2779 - val_loss: 0.8200 - val_model_loss: 0.1563 - val_model_1_loss: 0.1465 - val_output_layer_loss: 0.2041 - val_model_mae: 0.0967 - val_model_acc: 0.9364 - val_model_1_mae: 0.0941 - val_model_1_acc: 0.9399 - val_output_layer_mae: 0.6353 - val_output_layer_acc: 0.2812
# Epoch 46/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.7815 - model_loss: 0.1402 - model_1_loss: 0.1330 - output_layer_loss: 0.1965 - model_mae: 0.0795 - model_acc: 0.9370 - model_1_mae: 0.0764 - model_1_acc: 0.9413 - output_layer_mae: 0.6199 - output_layer_acc: 0.2952 - val_loss: 0.7927 - val_model_loss: 0.1509 - val_model_1_loss: 0.1470 - val_output_layer_loss: 0.1866 - val_model_mae: 0.0927 - val_model_acc: 0.9374 - val_model_1_mae: 0.0913 - val_model_1_acc: 0.9383 - val_output_layer_mae: 0.6372 - val_output_layer_acc: 0.2500
# Epoch 47/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.7668 - model_loss: 0.1352 - model_1_loss: 0.1365 - output_layer_loss: 0.1882 - model_mae: 0.0769 - model_acc: 0.9393 - model_1_mae: 0.0770 - model_1_acc: 0.9399 - output_layer_mae: 0.6395 - output_layer_acc: 0.3070 - val_loss: 0.7684 - val_model_loss: 0.1509 - val_model_1_loss: 0.1384 - val_output_layer_loss: 0.1755 - val_model_mae: 0.0902 - val_model_acc: 0.9326 - val_model_1_mae: 0.0851 - val_model_1_acc: 0.9398 - val_output_layer_mae: 0.6719 - val_output_layer_acc: 0.2500
# Epoch 48/100
# 20/20 [==============================] - 222s 11s/step - loss: 0.7649 - model_loss: 0.1355 - model_1_loss: 0.1406 - output_layer_loss: 0.1863 - model_mae: 0.0773 - model_acc: 0.9406 - model_1_mae: 0.0786 - model_1_acc: 0.9385 - output_layer_mae: 0.6502 - output_layer_acc: 0.2949 - val_loss: 0.7393 - val_model_loss: 0.1336 - val_model_1_loss: 0.1385 - val_output_layer_loss: 0.1679 - val_model_mae: 0.0869 - val_model_acc: 0.9440 - val_model_1_mae: 0.0881 - val_model_1_acc: 0.9401 - val_output_layer_mae: 0.6896 - val_output_layer_acc: 0.2292
# Epoch 49/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.7731 - model_loss: 0.1416 - model_1_loss: 0.1348 - output_layer_loss: 0.1986 - model_mae: 0.0815 - model_acc: 0.9362 - model_1_mae: 0.0793 - model_1_acc: 0.9388 - output_layer_mae: 0.6758 - output_layer_acc: 0.2717 - val_loss: 0.8502 - val_model_loss: 0.1868 - val_model_1_loss: 0.1832 - val_output_layer_loss: 0.1858 - val_model_mae: 0.1165 - val_model_acc: 0.9208 - val_model_1_mae: 0.1147 - val_model_1_acc: 0.9238 - val_output_layer_mae: 0.6455 - val_output_layer_acc: 0.3125
# Epoch 50/100
# 20/20 [==============================] - 222s 11s/step - loss: 0.7890 - model_loss: 0.1565 - model_1_loss: 0.1620 - output_layer_loss: 0.1769 - model_mae: 0.0853 - model_acc: 0.9345 - model_1_mae: 0.0877 - model_1_acc: 0.9308 - output_layer_mae: 0.6628 - output_layer_acc: 0.2598 - val_loss: 0.7896 - val_model_loss: 0.1574 - val_model_1_loss: 0.1520 - val_output_layer_loss: 0.1888 - val_model_mae: 0.0972 - val_model_acc: 0.9324 - val_model_1_mae: 0.0952 - val_model_1_acc: 0.9350 - val_output_layer_mae: 0.6707 - val_output_layer_acc: 0.3229
# Epoch 51/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.7793 - model_loss: 0.1411 - model_1_loss: 0.1377 - output_layer_loss: 0.2097 - model_mae: 0.0830 - model_acc: 0.9385 - model_1_mae: 0.0820 - model_1_acc: 0.9393 - output_layer_mae: 0.6217 - output_layer_acc: 0.3182 - val_loss: 0.8513 - val_model_loss: 0.1769 - val_model_1_loss: 0.1754 - val_output_layer_loss: 0.2097 - val_model_mae: 0.1105 - val_model_acc: 0.9252 - val_model_1_mae: 0.1089 - val_model_1_acc: 0.9265 - val_output_layer_mae: 0.6647 - val_output_layer_acc: 0.3125
# Epoch 52/100
# 20/20 [==============================] - 222s 11s/step - loss: 0.7628 - model_loss: 0.1347 - model_1_loss: 0.1420 - output_layer_loss: 0.1971 - model_mae: 0.0783 - model_acc: 0.9390 - model_1_mae: 0.0803 - model_1_acc: 0.9367 - output_layer_mae: 0.6757 - output_layer_acc: 0.2788 - val_loss: 0.7891 - val_model_loss: 0.1589 - val_model_1_loss: 0.1534 - val_output_layer_loss: 0.1889 - val_model_mae: 0.0975 - val_model_acc: 0.9329 - val_model_1_mae: 0.0955 - val_model_1_acc: 0.9350 - val_output_layer_mae: 0.6945 - val_output_layer_acc: 0.2917
# Epoch 53/100
# 20/20 [==============================] - 222s 11s/step - loss: 0.7612 - model_loss: 0.1415 - model_1_loss: 0.1338 - output_layer_loss: 0.1985 - model_mae: 0.0810 - model_acc: 0.9365 - model_1_mae: 0.0780 - model_1_acc: 0.9397 - output_layer_mae: 0.6609 - output_layer_acc: 0.3362 - val_loss: 0.7808 - val_model_loss: 0.1588 - val_model_1_loss: 0.1378 - val_output_layer_loss: 0.1987 - val_model_mae: 0.0947 - val_model_acc: 0.9321 - val_model_1_mae: 0.0873 - val_model_1_acc: 0.9424 - val_output_layer_mae: 0.6829 - val_output_layer_acc: 0.3125
# Epoch 54/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.7479 - model_loss: 0.1309 - model_1_loss: 0.1343 - output_layer_loss: 0.1982 - model_mae: 0.0736 - model_acc: 0.9412 - model_1_mae: 0.0752 - model_1_acc: 0.9391 - output_layer_mae: 0.6578 - output_layer_acc: 0.3053 - val_loss: 0.7485 - val_model_loss: 0.1455 - val_model_1_loss: 0.1329 - val_output_layer_loss: 0.1882 - val_model_mae: 0.0901 - val_model_acc: 0.9360 - val_model_1_mae: 0.0847 - val_model_1_acc: 0.9433 - val_output_layer_mae: 0.6778 - val_output_layer_acc: 0.2917
# Epoch 55/100
# 20/20 [==============================] - 222s 11s/step - loss: 0.7342 - model_loss: 0.1336 - model_1_loss: 0.1316 - output_layer_loss: 0.1882 - model_mae: 0.0776 - model_acc: 0.9377 - model_1_mae: 0.0764 - model_1_acc: 0.9396 - output_layer_mae: 0.6638 - output_layer_acc: 0.2802 - val_loss: 0.7441 - val_model_loss: 0.1496 - val_model_1_loss: 0.1422 - val_output_layer_loss: 0.1743 - val_model_mae: 0.0917 - val_model_acc: 0.9372 - val_model_1_mae: 0.0891 - val_model_1_acc: 0.9393 - val_output_layer_mae: 0.6891 - val_output_layer_acc: 0.2708
# Epoch 56/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.7125 - model_loss: 0.1254 - model_1_loss: 0.1303 - output_layer_loss: 0.1795 - model_mae: 0.0726 - model_acc: 0.9419 - model_1_mae: 0.0744 - model_1_acc: 0.9393 - output_layer_mae: 0.6540 - output_layer_acc: 0.2530 - val_loss: 0.7468 - val_model_loss: 0.1452 - val_model_1_loss: 0.1641 - val_output_layer_loss: 0.1633 - val_model_mae: 0.0875 - val_model_acc: 0.9370 - val_model_1_mae: 0.0918 - val_model_1_acc: 0.9322 - val_output_layer_mae: 0.6875 - val_output_layer_acc: 0.2500
# Epoch 57/100
# 20/20 [==============================] - 222s 11s/step - loss: 0.7248 - model_loss: 0.1332 - model_1_loss: 0.1261 - output_layer_loss: 0.1923 - model_mae: 0.0759 - model_acc: 0.9388 - model_1_mae: 0.0734 - model_1_acc: 0.9420 - output_layer_mae: 0.6348 - output_layer_acc: 0.2771 - val_loss: 0.7486 - val_model_loss: 0.1552 - val_model_1_loss: 0.1563 - val_output_layer_loss: 0.1667 - val_model_mae: 0.0964 - val_model_acc: 0.9359 - val_model_1_mae: 0.0973 - val_model_1_acc: 0.9340 - val_output_layer_mae: 0.6935 - val_output_layer_acc: 0.2292
# Epoch 58/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.7139 - model_loss: 0.1288 - model_1_loss: 0.1250 - output_layer_loss: 0.1908 - model_mae: 0.0739 - model_acc: 0.9410 - model_1_mae: 0.0730 - model_1_acc: 0.9420 - output_layer_mae: 0.6707 - output_layer_acc: 0.3094 - val_loss: 0.7031 - val_model_loss: 0.1420 - val_model_1_loss: 0.1292 - val_output_layer_loss: 0.1655 - val_model_mae: 0.0847 - val_model_acc: 0.9371 - val_model_1_mae: 0.0795 - val_model_1_acc: 0.9434 - val_output_layer_mae: 0.6962 - val_output_layer_acc: 0.2188
# Epoch 59/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.6817 - model_loss: 0.1264 - model_1_loss: 0.1285 - output_layer_loss: 0.1616 - model_mae: 0.0709 - model_acc: 0.9409 - model_1_mae: 0.0712 - model_1_acc: 0.9399 - output_layer_mae: 0.6827 - output_layer_acc: 0.2040 - val_loss: 0.7531 - val_model_loss: 0.1443 - val_model_1_loss: 0.1537 - val_output_layer_loss: 0.1927 - val_model_mae: 0.0870 - val_model_acc: 0.9388 - val_model_1_mae: 0.0900 - val_model_1_acc: 0.9355 - val_output_layer_mae: 0.6870 - val_output_layer_acc: 0.3646
# Epoch 60/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.7164 - model_loss: 0.1276 - model_1_loss: 0.1198 - output_layer_loss: 0.2075 - model_mae: 0.0735 - model_acc: 0.9398 - model_1_mae: 0.0708 - model_1_acc: 0.9431 - output_layer_mae: 0.6222 - output_layer_acc: 0.2999 - val_loss: 0.7391 - val_model_loss: 0.1452 - val_model_1_loss: 0.1516 - val_output_layer_loss: 0.1833 - val_model_mae: 0.0940 - val_model_acc: 0.9365 - val_model_1_mae: 0.0950 - val_model_1_acc: 0.9354 - val_output_layer_mae: 0.6583 - val_output_layer_acc: 0.2812
# Epoch 61/100
# 20/20 [==============================] - 222s 11s/step - loss: 0.6816 - model_loss: 0.1149 - model_1_loss: 0.1252 - output_layer_loss: 0.1831 - model_mae: 0.0700 - model_acc: 0.9452 - model_1_mae: 0.0739 - model_1_acc: 0.9403 - output_layer_mae: 0.6513 - output_layer_acc: 0.2890 - val_loss: 0.7497 - val_model_loss: 0.1393 - val_model_1_loss: 0.1466 - val_output_layer_loss: 0.2076 - val_model_mae: 0.0796 - val_model_acc: 0.9401 - val_model_1_mae: 0.0817 - val_model_1_acc: 0.9369 - val_output_layer_mae: 0.8053 - val_output_layer_acc: 0.2812
# Epoch 62/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.6934 - model_loss: 0.1238 - model_1_loss: 0.1226 - output_layer_loss: 0.1916 - model_mae: 0.0651 - model_acc: 0.9424 - model_1_mae: 0.0647 - model_1_acc: 0.9431 - output_layer_mae: 0.6903 - output_layer_acc: 0.2989 - val_loss: 0.7547 - val_model_loss: 0.1561 - val_model_1_loss: 0.1620 - val_output_layer_loss: 0.1839 - val_model_mae: 0.1046 - val_model_acc: 0.9399 - val_model_1_mae: 0.1056 - val_model_1_acc: 0.9370 - val_output_layer_mae: 0.7140 - val_output_layer_acc: 0.2604
# Epoch 63/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.6924 - model_loss: 0.1165 - model_1_loss: 0.1241 - output_layer_loss: 0.1998 - model_mae: 0.0713 - model_acc: 0.9438 - model_1_mae: 0.0735 - model_1_acc: 0.9420 - output_layer_mae: 0.6446 - output_layer_acc: 0.2907 - val_loss: 0.7163 - val_model_loss: 0.1451 - val_model_1_loss: 0.1462 - val_output_layer_loss: 0.1757 - val_model_mae: 0.0967 - val_model_acc: 0.9436 - val_model_1_mae: 0.0971 - val_model_1_acc: 0.9422 - val_output_layer_mae: 0.6893 - val_output_layer_acc: 0.2812
# Epoch 64/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.6743 - model_loss: 0.1211 - model_1_loss: 0.1164 - output_layer_loss: 0.1883 - model_mae: 0.0706 - model_acc: 0.9402 - model_1_mae: 0.0684 - model_1_acc: 0.9435 - output_layer_mae: 0.6516 - output_layer_acc: 0.2838 - val_loss: 0.7104 - val_model_loss: 0.1309 - val_model_1_loss: 0.1252 - val_output_layer_loss: 0.2084 - val_model_mae: 0.0850 - val_model_acc: 0.9427 - val_model_1_mae: 0.0826 - val_model_1_acc: 0.9444 - val_output_layer_mae: 0.6315 - val_output_layer_acc: 0.3021
# Epoch 65/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.6731 - model_loss: 0.1140 - model_1_loss: 0.1115 - output_layer_loss: 0.2024 - model_mae: 0.0680 - model_acc: 0.9450 - model_1_mae: 0.0674 - model_1_acc: 0.9456 - output_layer_mae: 0.6193 - output_layer_acc: 0.3305 - val_loss: 0.6678 - val_model_loss: 0.1280 - val_model_1_loss: 0.1306 - val_output_layer_loss: 0.1662 - val_model_mae: 0.0766 - val_model_acc: 0.9432 - val_model_1_mae: 0.0776 - val_model_1_acc: 0.9417 - val_output_layer_mae: 0.6734 - val_output_layer_acc: 0.2292
# Epoch 66/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.6350 - model_loss: 0.1128 - model_1_loss: 0.1140 - output_layer_loss: 0.1659 - model_mae: 0.0647 - model_acc: 0.9451 - model_1_mae: 0.0655 - model_1_acc: 0.9442 - output_layer_mae: 0.6907 - output_layer_acc: 0.2278 - val_loss: 0.7021 - val_model_loss: 0.1385 - val_model_1_loss: 0.1454 - val_output_layer_loss: 0.1781 - val_model_mae: 0.0920 - val_model_acc: 0.9434 - val_model_1_mae: 0.0941 - val_model_1_acc: 0.9408 - val_output_layer_mae: 0.6656 - val_output_layer_acc: 0.2604
# Epoch 67/100
# 20/20 [==============================] - 226s 11s/step - loss: 0.7204 - model_loss: 0.1361 - model_1_loss: 0.1361 - output_layer_loss: 0.2089 - model_mae: 0.0776 - model_acc: 0.9357 - model_1_mae: 0.0771 - model_1_acc: 0.9365 - output_layer_mae: 0.6515 - output_layer_acc: 0.3031 - val_loss: 0.7240 - val_model_loss: 0.1516 - val_model_1_loss: 0.1411 - val_output_layer_loss: 0.1937 - val_model_mae: 0.0992 - val_model_acc: 0.9322 - val_model_1_mae: 0.0944 - val_model_1_acc: 0.9390 - val_output_layer_mae: 0.6360 - val_output_layer_acc: 0.2917
# Epoch 68/100
# 20/20 [==============================] - 225s 11s/step - loss: 0.7052 - model_loss: 0.1253 - model_1_loss: 0.1256 - output_layer_loss: 0.2174 - model_mae: 0.0726 - model_acc: 0.9399 - model_1_mae: 0.0726 - model_1_acc: 0.9399 - output_layer_mae: 0.6082 - output_layer_acc: 0.3132 - val_loss: 0.7193 - val_model_loss: 0.1501 - val_model_1_loss: 0.1572 - val_output_layer_loss: 0.1769 - val_model_mae: 0.0976 - val_model_acc: 0.9393 - val_model_1_mae: 0.1004 - val_model_1_acc: 0.9361 - val_output_layer_mae: 0.6733 - val_output_layer_acc: 0.2396
# Epoch 69/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.6504 - model_loss: 0.1202 - model_1_loss: 0.1135 - output_layer_loss: 0.1823 - model_mae: 0.0718 - model_acc: 0.9419 - model_1_mae: 0.0694 - model_1_acc: 0.9450 - output_layer_mae: 0.6556 - output_layer_acc: 0.2818 - val_loss: 0.6652 - val_model_loss: 0.1211 - val_model_1_loss: 0.1265 - val_output_layer_loss: 0.1852 - val_model_mae: 0.0763 - val_model_acc: 0.9461 - val_model_1_mae: 0.0785 - val_model_1_acc: 0.9424 - val_output_layer_mae: 0.6405 - val_output_layer_acc: 0.2708
# Epoch 70/100
# 20/20 [==============================] - 222s 11s/step - loss: 0.6480 - model_loss: 0.1144 - model_1_loss: 0.1118 - output_layer_loss: 0.1898 - model_mae: 0.0666 - model_acc: 0.9434 - model_1_mae: 0.0658 - model_1_acc: 0.9447 - output_layer_mae: 0.6637 - output_layer_acc: 0.3138 - val_loss: 0.6777 - val_model_loss: 0.1392 - val_model_1_loss: 0.1311 - val_output_layer_loss: 0.1773 - val_model_mae: 0.0832 - val_model_acc: 0.9345 - val_model_1_mae: 0.0807 - val_model_1_acc: 0.9374 - val_output_layer_mae: 0.6933 - val_output_layer_acc: 0.2708
# Epoch 71/100
# 20/20 [==============================] - 226s 11s/step - loss: 0.6510 - model_loss: 0.1180 - model_1_loss: 0.1182 - output_layer_loss: 0.1856 - model_mae: 0.0690 - model_acc: 0.9417 - model_1_mae: 0.0691 - model_1_acc: 0.9413 - output_layer_mae: 0.6747 - output_layer_acc: 0.2650 - val_loss: 0.6469 - val_model_loss: 0.1192 - val_model_1_loss: 0.1155 - val_output_layer_loss: 0.1853 - val_model_mae: 0.0747 - val_model_acc: 0.9440 - val_model_1_mae: 0.0722 - val_model_1_acc: 0.9477 - val_output_layer_mae: 0.6891 - val_output_layer_acc: 0.2500
# Epoch 72/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.6126 - model_loss: 0.1079 - model_1_loss: 0.1105 - output_layer_loss: 0.1682 - model_mae: 0.0634 - model_acc: 0.9464 - model_1_mae: 0.0642 - model_1_acc: 0.9451 - output_layer_mae: 0.6863 - output_layer_acc: 0.2482 - val_loss: 0.6704 - val_model_loss: 0.1384 - val_model_1_loss: 0.1353 - val_output_layer_loss: 0.1734 - val_model_mae: 0.0945 - val_model_acc: 0.9425 - val_model_1_mae: 0.0913 - val_model_1_acc: 0.9429 - val_output_layer_mae: 0.7047 - val_output_layer_acc: 0.2396
# Epoch 73/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.6307 - model_loss: 0.1168 - model_1_loss: 0.1164 - output_layer_loss: 0.1750 - model_mae: 0.0709 - model_acc: 0.9422 - model_1_mae: 0.0710 - model_1_acc: 0.9419 - output_layer_mae: 0.6915 - output_layer_acc: 0.2337 - val_loss: 0.6359 - val_model_loss: 0.1235 - val_model_1_loss: 0.1227 - val_output_layer_loss: 0.1699 - val_model_mae: 0.0837 - val_model_acc: 0.9435 - val_model_1_mae: 0.0824 - val_model_1_acc: 0.9434 - val_output_layer_mae: 0.7190 - val_output_layer_acc: 0.2604
# Epoch 74/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.6362 - model_loss: 0.1139 - model_1_loss: 0.1142 - output_layer_loss: 0.1890 - model_mae: 0.0668 - model_acc: 0.9434 - model_1_mae: 0.0670 - model_1_acc: 0.9432 - output_layer_mae: 0.6703 - output_layer_acc: 0.3209 - val_loss: 0.6265 - val_model_loss: 0.1354 - val_model_1_loss: 0.1351 - val_output_layer_loss: 0.1389 - val_model_mae: 0.0855 - val_model_acc: 0.9383 - val_model_1_mae: 0.0848 - val_model_1_acc: 0.9392 - val_output_layer_mae: 0.8333 - val_output_layer_acc: 0.2188
# Epoch 75/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.6442 - model_loss: 0.1101 - model_1_loss: 0.1183 - output_layer_loss: 0.1992 - model_mae: 0.0648 - model_acc: 0.9451 - model_1_mae: 0.0675 - model_1_acc: 0.9418 - output_layer_mae: 0.6902 - output_layer_acc: 0.2946 - val_loss: 0.6858 - val_model_loss: 0.1119 - val_model_1_loss: 0.1231 - val_output_layer_loss: 0.2350 - val_model_mae: 0.0709 - val_model_acc: 0.9472 - val_model_1_mae: 0.0748 - val_model_1_acc: 0.9408 - val_output_layer_mae: 0.5999 - val_output_layer_acc: 0.3854
# Epoch 76/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.6530 - model_loss: 0.1118 - model_1_loss: 0.1086 - output_layer_loss: 0.2159 - model_mae: 0.0649 - model_acc: 0.9439 - model_1_mae: 0.0634 - model_1_acc: 0.9459 - output_layer_mae: 0.6347 - output_layer_acc: 0.3303 - val_loss: 0.6255 - val_model_loss: 0.1174 - val_model_1_loss: 0.1175 - val_output_layer_loss: 0.1736 - val_model_mae: 0.0745 - val_model_acc: 0.9452 - val_model_1_mae: 0.0734 - val_model_1_acc: 0.9445 - val_output_layer_mae: 0.6644 - val_output_layer_acc: 0.2083
# Epoch 77/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.6137 - model_loss: 0.1145 - model_1_loss: 0.1052 - output_layer_loss: 0.1768 - model_mae: 0.0658 - model_acc: 0.9426 - model_1_mae: 0.0624 - model_1_acc: 0.9467 - output_layer_mae: 0.6812 - output_layer_acc: 0.2570 - val_loss: 0.6253 - val_model_loss: 0.1101 - val_model_1_loss: 0.1145 - val_output_layer_loss: 0.1835 - val_model_mae: 0.0744 - val_model_acc: 0.9488 - val_model_1_mae: 0.0760 - val_model_1_acc: 0.9450 - val_output_layer_mae: 0.6839 - val_output_layer_acc: 0.2500
# Epoch 78/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.6200 - model_loss: 0.1075 - model_1_loss: 0.1101 - output_layer_loss: 0.1851 - model_mae: 0.0640 - model_acc: 0.9457 - model_1_mae: 0.0650 - model_1_acc: 0.9446 - output_layer_mae: 0.6657 - output_layer_acc: 0.2517 - val_loss: 0.6844 - val_model_loss: 0.1362 - val_model_1_loss: 0.1339 - val_output_layer_loss: 0.1939 - val_model_mae: 0.0866 - val_model_acc: 0.9378 - val_model_1_mae: 0.0845 - val_model_1_acc: 0.9411 - val_output_layer_mae: 0.6617 - val_output_layer_acc: 0.2812
# Epoch 79/100
# 20/20 [==============================] - 222s 11s/step - loss: 0.6506 - model_loss: 0.1143 - model_1_loss: 0.1118 - output_layer_loss: 0.2027 - model_mae: 0.0669 - model_acc: 0.9433 - model_1_mae: 0.0662 - model_1_acc: 0.9446 - output_layer_mae: 0.6321 - output_layer_acc: 0.2874 - val_loss: 0.6443 - val_model_loss: 0.1332 - val_model_1_loss: 0.1347 - val_output_layer_loss: 0.1517 - val_model_mae: 0.0860 - val_model_acc: 0.9383 - val_model_1_mae: 0.0856 - val_model_1_acc: 0.9383 - val_output_layer_mae: 0.7385 - val_output_layer_acc: 0.2083
# Epoch 80/100
# 20/20 [==============================] - 222s 11s/step - loss: 0.6349 - model_loss: 0.1179 - model_1_loss: 0.1135 - output_layer_loss: 0.1797 - model_mae: 0.0681 - model_acc: 0.9402 - model_1_mae: 0.0664 - model_1_acc: 0.9429 - output_layer_mae: 0.7092 - output_layer_acc: 0.2224 - val_loss: 0.6538 - val_model_loss: 0.1252 - val_model_1_loss: 0.1213 - val_output_layer_loss: 0.1865 - val_model_mae: 0.0788 - val_model_acc: 0.9416 - val_model_1_mae: 0.0765 - val_model_1_acc: 0.9433 - val_output_layer_mae: 0.6437 - val_output_layer_acc: 0.3125
# Epoch 81/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.6340 - model_loss: 0.1086 - model_1_loss: 0.1108 - output_layer_loss: 0.1948 - model_mae: 0.0654 - model_acc: 0.9453 - model_1_mae: 0.0663 - model_1_acc: 0.9435 - output_layer_mae: 0.6560 - output_layer_acc: 0.2836 - val_loss: 0.6500 - val_model_loss: 0.1129 - val_model_1_loss: 0.1179 - val_output_layer_loss: 0.2023 - val_model_mae: 0.0713 - val_model_acc: 0.9461 - val_model_1_mae: 0.0726 - val_model_1_acc: 0.9440 - val_output_layer_mae: 0.6801 - val_output_layer_acc: 0.3021
# Epoch 82/100
# 20/20 [==============================] - 222s 11s/step - loss: 0.6124 - model_loss: 0.1103 - model_1_loss: 0.1087 - output_layer_loss: 0.1780 - model_mae: 0.0642 - model_acc: 0.9447 - model_1_mae: 0.0637 - model_1_acc: 0.9451 - output_layer_mae: 0.6749 - output_layer_acc: 0.2947 - val_loss: 0.6437 - val_model_loss: 0.1332 - val_model_1_loss: 0.1371 - val_output_layer_loss: 0.1623 - val_model_mae: 0.0919 - val_model_acc: 0.9410 - val_model_1_mae: 0.0934 - val_model_1_acc: 0.9385 - val_output_layer_mae: 0.7083 - val_output_layer_acc: 0.2500
# Epoch 83/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.6136 - model_loss: 0.1057 - model_1_loss: 0.1085 - output_layer_loss: 0.1898 - model_mae: 0.0645 - model_acc: 0.9468 - model_1_mae: 0.0652 - model_1_acc: 0.9457 - output_layer_mae: 0.6419 - output_layer_acc: 0.3053 - val_loss: 0.6457 - val_model_loss: 0.1385 - val_model_1_loss: 0.1387 - val_output_layer_loss: 0.1627 - val_model_mae: 0.0927 - val_model_acc: 0.9382 - val_model_1_mae: 0.0919 - val_model_1_acc: 0.9377 - val_output_layer_mae: 0.6942 - val_output_layer_acc: 0.2292
# Epoch 84/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.5908 - model_loss: 0.1078 - model_1_loss: 0.1097 - output_layer_loss: 0.1686 - model_mae: 0.0661 - model_acc: 0.9451 - model_1_mae: 0.0668 - model_1_acc: 0.9442 - output_layer_mae: 0.6810 - output_layer_acc: 0.2622 - val_loss: 0.6077 - val_model_loss: 0.1162 - val_model_1_loss: 0.1106 - val_output_layer_loss: 0.1795 - val_model_mae: 0.0754 - val_model_acc: 0.9427 - val_model_1_mae: 0.0723 - val_model_1_acc: 0.9470 - val_output_layer_mae: 0.6482 - val_output_layer_acc: 0.2604
# Epoch 85/100
# 20/20 [==============================] - 222s 11s/step - loss: 0.6051 - model_loss: 0.1049 - model_1_loss: 0.1112 - output_layer_loss: 0.1887 - model_mae: 0.0633 - model_acc: 0.9457 - model_1_mae: 0.0654 - model_1_acc: 0.9438 - output_layer_mae: 0.6515 - output_layer_acc: 0.2736 - val_loss: 0.6354 - val_model_loss: 0.1301 - val_model_1_loss: 0.1279 - val_output_layer_loss: 0.1798 - val_model_mae: 0.0807 - val_model_acc: 0.9397 - val_model_1_mae: 0.0801 - val_model_1_acc: 0.9392 - val_output_layer_mae: 0.7692 - val_output_layer_acc: 0.2604
# Epoch 86/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.5793 - model_loss: 0.1027 - model_1_loss: 0.1065 - output_layer_loss: 0.1734 - model_mae: 0.0614 - model_acc: 0.9470 - model_1_mae: 0.0624 - model_1_acc: 0.9460 - output_layer_mae: 0.6889 - output_layer_acc: 0.2562 - val_loss: 0.5890 - val_model_loss: 0.1208 - val_model_1_loss: 0.1105 - val_output_layer_loss: 0.1638 - val_model_mae: 0.0771 - val_model_acc: 0.9408 - val_model_1_mae: 0.0726 - val_model_1_acc: 0.9468 - val_output_layer_mae: 0.7030 - val_output_layer_acc: 0.2604
# Epoch 87/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.5686 - model_loss: 0.1072 - model_1_loss: 0.1023 - output_layer_loss: 0.1660 - model_mae: 0.0616 - model_acc: 0.9462 - model_1_mae: 0.0603 - model_1_acc: 0.9476 - output_layer_mae: 0.7108 - output_layer_acc: 0.2406 - val_loss: 0.6146 - val_model_loss: 0.1259 - val_model_1_loss: 0.1189 - val_output_layer_loss: 0.1794 - val_model_mae: 0.0803 - val_model_acc: 0.9395 - val_model_1_mae: 0.0780 - val_model_1_acc: 0.9430 - val_output_layer_mae: 0.6808 - val_output_layer_acc: 0.2500
# Epoch 88/100
# 20/20 [==============================] - 233s 12s/step - loss: 0.5775 - model_loss: 0.1074 - model_1_loss: 0.1090 - output_layer_loss: 0.1715 - model_mae: 0.0647 - model_acc: 0.9449 - model_1_mae: 0.0652 - model_1_acc: 0.9440 - output_layer_mae: 0.6692 - output_layer_acc: 0.2570 - val_loss: 0.6408 - val_model_loss: 0.1284 - val_model_1_loss: 0.1242 - val_output_layer_loss: 0.2005 - val_model_mae: 0.0816 - val_model_acc: 0.9391 - val_model_1_mae: 0.0804 - val_model_1_acc: 0.9411 - val_output_layer_mae: 0.6369 - val_output_layer_acc: 0.3333
# Epoch 89/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.5893 - model_loss: 0.1092 - model_1_loss: 0.1068 - output_layer_loss: 0.1862 - model_mae: 0.0631 - model_acc: 0.9446 - model_1_mae: 0.0624 - model_1_acc: 0.9447 - output_layer_mae: 0.6665 - output_layer_acc: 0.2832 - val_loss: 0.6640 - val_model_loss: 0.1423 - val_model_1_loss: 0.1361 - val_output_layer_loss: 0.1999 - val_model_mae: 0.0831 - val_model_acc: 0.9317 - val_model_1_mae: 0.0804 - val_model_1_acc: 0.9360 - val_output_layer_mae: 0.6740 - val_output_layer_acc: 0.2812
# Epoch 90/100
# 20/20 [==============================] - 224s 11s/step - loss: 0.5775 - model_loss: 0.1053 - model_1_loss: 0.1114 - output_layer_loss: 0.1755 - model_mae: 0.0616 - model_acc: 0.9465 - model_1_mae: 0.0635 - model_1_acc: 0.9438 - output_layer_mae: 0.6820 - output_layer_acc: 0.2729 - val_loss: 0.6106 - val_model_loss: 0.1240 - val_model_1_loss: 0.1251 - val_output_layer_loss: 0.1778 - val_model_mae: 0.0854 - val_model_acc: 0.9422 - val_model_1_mae: 0.0856 - val_model_1_acc: 0.9404 - val_output_layer_mae: 0.6503 - val_output_layer_acc: 0.2500
# Epoch 91/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.5867 - model_loss: 0.1094 - model_1_loss: 0.1111 - output_layer_loss: 0.1831 - model_mae: 0.0644 - model_acc: 0.9441 - model_1_mae: 0.0649 - model_1_acc: 0.9432 - output_layer_mae: 0.6573 - output_layer_acc: 0.2723 - val_loss: 0.6012 - val_model_loss: 0.1153 - val_model_1_loss: 0.1281 - val_output_layer_loss: 0.1766 - val_model_mae: 0.0752 - val_model_acc: 0.9438 - val_model_1_mae: 0.0791 - val_model_1_acc: 0.9371 - val_output_layer_mae: 0.6663 - val_output_layer_acc: 0.2708
# Epoch 92/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.5691 - model_loss: 0.1053 - model_1_loss: 0.1084 - output_layer_loss: 0.1746 - model_mae: 0.0614 - model_acc: 0.9458 - model_1_mae: 0.0621 - model_1_acc: 0.9450 - output_layer_mae: 0.6877 - output_layer_acc: 0.2389 - val_loss: 0.6620 - val_model_loss: 0.1464 - val_model_1_loss: 0.1437 - val_output_layer_loss: 0.1932 - val_model_mae: 0.0997 - val_model_acc: 0.9327 - val_model_1_mae: 0.0969 - val_model_1_acc: 0.9362 - val_output_layer_mae: 0.6336 - val_output_layer_acc: 0.2604
# Epoch 93/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.5557 - model_loss: 0.1039 - model_1_loss: 0.1129 - output_layer_loss: 0.1607 - model_mae: 0.0639 - model_acc: 0.9473 - model_1_mae: 0.0669 - model_1_acc: 0.9431 - output_layer_mae: 0.7157 - output_layer_acc: 0.2439 - val_loss: 0.5842 - val_model_loss: 0.1147 - val_model_1_loss: 0.1196 - val_output_layer_loss: 0.1735 - val_model_mae: 0.0729 - val_model_acc: 0.9428 - val_model_1_mae: 0.0740 - val_model_1_acc: 0.9407 - val_output_layer_mae: 0.6809 - val_output_layer_acc: 0.2500
# Epoch 94/100
# 20/20 [==============================] - 224s 11s/step - loss: 0.5591 - model_loss: 0.1153 - model_1_loss: 0.1068 - output_layer_loss: 0.1611 - model_mae: 0.0666 - model_acc: 0.9413 - model_1_mae: 0.0634 - model_1_acc: 0.9457 - output_layer_mae: 0.7317 - output_layer_acc: 0.2466 - val_loss: 0.5975 - val_model_loss: 0.1233 - val_model_1_loss: 0.1278 - val_output_layer_loss: 0.1723 - val_model_mae: 0.0839 - val_model_acc: 0.9433 - val_model_1_mae: 0.0849 - val_model_1_acc: 0.9396 - val_output_layer_mae: 0.6656 - val_output_layer_acc: 0.2396
# Epoch 95/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.5413 - model_loss: 0.1055 - model_1_loss: 0.1025 - output_layer_loss: 0.1599 - model_mae: 0.0636 - model_acc: 0.9453 - model_1_mae: 0.0625 - model_1_acc: 0.9472 - output_layer_mae: 0.6854 - output_layer_acc: 0.2265 - val_loss: 0.5836 - val_model_loss: 0.1272 - val_model_1_loss: 0.1245 - val_output_layer_loss: 0.1603 - val_model_mae: 0.0823 - val_model_acc: 0.9381 - val_model_1_mae: 0.0805 - val_model_1_acc: 0.9387 - val_output_layer_mae: 0.7069 - val_output_layer_acc: 0.2188
# Epoch 96/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.5550 - model_loss: 0.1057 - model_1_loss: 0.1038 - output_layer_loss: 0.1746 - model_mae: 0.0623 - model_acc: 0.9457 - model_1_mae: 0.0616 - model_1_acc: 0.9465 - output_layer_mae: 0.6922 - output_layer_acc: 0.2731 - val_loss: 0.5649 - val_model_loss: 0.1200 - val_model_1_loss: 0.1124 - val_output_layer_loss: 0.1633 - val_model_mae: 0.0765 - val_model_acc: 0.9430 - val_model_1_mae: 0.0731 - val_model_1_acc: 0.9453 - val_output_layer_mae: 0.7075 - val_output_layer_acc: 0.2604
# Epoch 97/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.5409 - model_loss: 0.1065 - model_1_loss: 0.1056 - output_layer_loss: 0.1602 - model_mae: 0.0647 - model_acc: 0.9449 - model_1_mae: 0.0645 - model_1_acc: 0.9452 - output_layer_mae: 0.6918 - output_layer_acc: 0.2034 - val_loss: 0.6201 - val_model_loss: 0.1283 - val_model_1_loss: 0.1282 - val_output_layer_loss: 0.1968 - val_model_mae: 0.0822 - val_model_acc: 0.9395 - val_model_1_mae: 0.0825 - val_model_1_acc: 0.9385 - val_output_layer_mae: 0.6774 - val_output_layer_acc: 0.3542
# Epoch 98/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.5398 - model_loss: 0.1047 - model_1_loss: 0.1091 - output_layer_loss: 0.1597 - model_mae: 0.0626 - model_acc: 0.9448 - model_1_mae: 0.0636 - model_1_acc: 0.9439 - output_layer_mae: 0.7029 - output_layer_acc: 0.2398 - val_loss: 0.5829 - val_model_loss: 0.1148 - val_model_1_loss: 0.1226 - val_output_layer_loss: 0.1806 - val_model_mae: 0.0778 - val_model_acc: 0.9452 - val_model_1_mae: 0.0797 - val_model_1_acc: 0.9389 - val_output_layer_mae: 0.6875 - val_output_layer_acc: 0.2708
# Epoch 99/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.5414 - model_loss: 0.1042 - model_1_loss: 0.1028 - output_layer_loss: 0.1699 - model_mae: 0.0611 - model_acc: 0.9454 - model_1_mae: 0.0603 - model_1_acc: 0.9472 - output_layer_mae: 0.6797 - output_layer_acc: 0.2418 - val_loss: 0.5745 - val_model_loss: 0.1174 - val_model_1_loss: 0.1233 - val_output_layer_loss: 0.1708 - val_model_mae: 0.0772 - val_model_acc: 0.9446 - val_model_1_mae: 0.0785 - val_model_1_acc: 0.9411 - val_output_layer_mae: 0.6834 - val_output_layer_acc: 0.2604
# Epoch 100/100
# 20/20 [==============================] - 223s 11s/step - loss: 0.5433 - model_loss: 0.1026 - model_1_loss: 0.1008 - output_layer_loss: 0.1775 - model_mae: 0.0617 - model_acc: 0.9469 - model_1_mae: 0.0610 - model_1_acc: 0.9478 - output_layer_mae: 0.6705 - output_layer_acc: 0.2704 - val_loss: 0.5652 - val_model_loss: 0.1138 - val_model_1_loss: 0.1092 - val_output_layer_loss: 0.1812 - val_model_mae: 0.0737 - val_model_acc: 0.9436 - val_model_1_mae: 0.0714 - val_model_1_acc: 0.9456 - val_output_layer_mae: 0.7170 - val_output_layer_acc: 0.2812

# %%
# import matplotlib.pyplot as plt
# # Let's take a look at how we did during training.
# acc = history.history['model_acc']
# val_acc = history.history['val_model_acc']

# loss = history.history['model_loss']
# val_loss = history.history['val_model_loss']
# epochs = range(len(acc))

# # Accuracy
# fig, ax = plt.subplots(1, 2, figsize=(30, 10))
# ax[0].plot(epochs, acc, 'r', label='Training accuracy')
# ax[0].plot(epochs, val_acc, 'b', label='Validation accuracy')
# ax[0].set_title('Training and validation accuracy')
# ax[0].legend()

# # Loss
# ax[1].plot(epochs, loss, 'r', label='Training Loss')
# ax[1].plot(epochs, val_loss, 'b', label='Validation Loss')
# ax[1].set_title('Training and validation loss')
# ax[1].legend()

# plt.show()

# %%
model_save_path = '/tensorflow/siamese_model/siamese_unet_pixel_half_no_mask_seg_rotation_100epoch_80_train_test_casia.h5'
model.save(model_save_path)

# %%
#model = load_model(model_save_path,custom_objects={'contrastive_loss':contrastive_loss_with_margin(margin=1)})

# %%
Out = next((imageLoader(path_input_images,folder_name_list_test,1)))

# %%
images_L_R = Out[0]
image_L = images_L_R[0]
image_R = images_L_R[1]

mask_L_R_class = Out[1]

mask_L = mask_L_R_class[0]
mask_R = mask_L_R_class[1]
y = mask_L_R_class[2]
print(y[0])
print(image_L.shape)
#plt.title('left_mask')
#plt.imshow(np.squeeze(mask_R[1]))
#plt.imshow(image_R[1])
#plt.show()
# Out:
# 1.0
# (4, 128, 128, 1)

# %%
preds = model.predict([image_L,image_R])

# %%
#plt.imshow(np.squeeze(mask_R[1]))
plt.imshow(image_R[1],cmap='gray')
plt.show()

# %%
out_image = np.squeeze(preds[1][1])
preds[0].shape
# Out:
# (4, 128, 128, 1)

# %%
dummy_image = image_R[1].copy() 
dummy_image[out_image<.5] = 0
plt.imshow(dummy_image,cmap='gray')
plt.show()

# %%
y = preds[2]
print(y)

# %% [markdown]
# ## Test data for model

# %%
test_out1,test_out2,test_seg1,test_seg2,y_class = read_simaese_parametric_data(path_input_images,folder_name_list_test[0:50],50)

# %%
test_out1 = test_out1/255.0
test_out2 = test_out2/255.0
# test_seg1 = test_seg1/255.0
# test_seg2 = test_seg2/255.0

# %%
[test_seg_out1,test_seg_out2, y_pred] = model.predict([test_out1,test_out2])

# %%
test_seg2.shape
# Out:
# (200, 128, 128, 1)

# %%
def show_images(test_out1,test_seg_out1):
    #num_images = len(test_seg_out1)
    num_images = 20
    for i in range(0,num_images,4):
        dummy_image = np.squeeze(test_out1[i]).copy()
        seg_img = np.squeeze(test_seg_out1[i])
        dummy_image[seg_img<.5] = 0
        plt.imshow(np.squeeze(test_out1[i]),cmap='gray')
        plt.show()
        plt.imshow(dummy_image,cmap='gray')
        plt.show()

# %%
show_images(test_out2,test_seg_out2)

# %%
def compute_accuracy(y_true, y_pred):
    '''Compute classification accuracy with a fixed threshold on distances.
    '''
    pred = y_pred.ravel() < 0.5
    return np.mean(pred == y_true)

# %%
compute_accuracy(y_class, y_pred)      ## trained on 120 images and tested on 100 persons
# Out:
# 0.72

# %%
# !{sys.executable} -m pip install -U scikit-learn scipy

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_class, y_pred.ravel() < 0.5)                      ##   [TN , FP]
                                                                     ##     [FN , TP]

# %%
def rotate_image_tensor(image, angle, mode='black'):
    """
    Rotates a 3D tensor (HWD), which represents an image by given radian angle.

    New image has the same size as the input image.

    mode controls what happens to border pixels.
    mode = 'black' results in black bars (value 0 in unknown areas)
    mode = 'white' results in value 255 in unknown areas
    mode = 'ones' results in value 1 in unknown areas
    mode = 'repeat' keeps repeating the closest pixel known
    """
    s = image.get_shape().as_list()
    assert len(s) == 3, "Input needs to be 3D."
    assert (mode == 'repeat') or (mode == 'black') or (mode == 'white') or (mode == 'ones'), "Unknown boundary mode."
    image_center = [np.floor(x/2) for x in s]

    # Coordinates of new image
    coord1 = tf.range(s[0])
    coord2 = tf.range(s[1])

    # Create vectors of those coordinates in order to vectorize the image
    coord1_vec = tf.tile(coord1, [s[1]])

    coord2_vec_unordered = tf.tile(coord2, [s[0]])
    coord2_vec_unordered = tf.reshape(coord2_vec_unordered, [s[0], s[1]])
    coord2_vec = tf.reshape(tf.transpose(coord2_vec_unordered, [1, 0]), [-1])

    # center coordinates since rotation center is supposed to be in the image center
    coord1_vec_centered = coord1_vec - image_center[0]
    coord2_vec_centered = coord2_vec - image_center[1]

    coord_new_centered = tf.cast(tf.pack([coord1_vec_centered, coord2_vec_centered]), tf.float32)

# %%
  image = tf.constant(np.zeros((384, 512, 5)), dtype = tf.float32)
  image = tfa.image.rotate(image, tf.random.uniform(shape = [], minval = -0.3, maxval = 0.3))

# %%
tf.random.uniform(shape = [], minval = -0.3, maxval = 0.3)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.07962942>

# %%
tf.constant(0,dtype='float32')
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.0>

# %%
128*5 # (2*np.pi/360)*
# Out:
# 640

# %%
c = tf.constant([1.0, 2.0, 3.0, 4.0])          #2x4 
d = tf.constant([3.0, 4.0, 1.0,2.0])

# %%
print(concatenate([c,d],axis=0)[0:4])
# Out:
# tf.Tensor([1. 2. 3. 4.], shape=(4,), dtype=float32)

# %%
# a = tf.squeeze(tf.constant(np.zeros((None,512)),dtype=tf.float32))
a = tf.zeros([None, 4], tf.float32)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py in zeros(shape, dtype, name)
#    2873         shape = constant_op._tensor_shape_tensor_conversion_function(
# -> 2874             tensor_shape.TensorShape(shape))
#    2875       except (TypeError, ValueError):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in _tensor_shape_tensor_conversion_function(s, dtype, name, as_ref)
#     355     raise ValueError(
# --> 356         "Cannot convert a partially known TensorShape to a Tensor: %s" % s)
#     357   s_list = s.as_list()
#
# ValueError: Cannot convert a partially known TensorShape to a Tensor: (None, 4)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-e56ad6eb3c6b> in <module>
#       1 # a = tf.squeeze(tf.constant(np.zeros((None,512)),dtype=tf.float32))
# ----> 2 a = tf.zeros([None, 4], tf.float32)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py in wrapped(*args, **kwargs)
#    2817
#    2818   def wrapped(*args, **kwargs):
# -> 2819     tensor = fun(*args, **kwargs)
#    2820     tensor._is_zeros_tensor = True
#    2821     return tensor
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py in zeros(shape, dtype, name)
#    2875       except (TypeError, ValueError):
#    2876         # Happens when shape is a list with tensor elements
# -> 2877         shape = ops.convert_to_tensor(shape, dtype=dtypes.int32)
#    2878     if not shape._shape_tuple():
#    2879       shape = reshape(shape, [-1])  # Ensure it's a vector
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1538
#    1539     if ret is None:
# -> 1540       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1541
#    1542     if ret is NotImplemented:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     337                                          as_ref=False):
#     338   _ = as_ref
# --> 339   return constant(v, dtype=dtype, name=name)
#     340
#     341
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     263   """
#     264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 265                         allow_broadcast=True)
#     266
#     267
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     274       with trace.Trace("tf.constant"):
#     275         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 276     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277
#     278   g = ops.get_default_graph()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     299 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     300   """Implementation of eager constant."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# ValueError: Attempt to convert a value (None) with an unsupported type (<class 'NoneType'>) to a Tensor.

# %%
a
